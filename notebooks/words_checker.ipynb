# %%
import re
import sys
import pathlib
from typing import List
from IPython.display import Audio

import deepcut
import pandas as pd
import numpy as np
import thaispellcheck
from langdetect import detect
from string import punctuation
from pythainlp import word_vector
from pythainlp.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity

ROOT_DIR = pathlib.Path.cwd().parent
sys.path.insert(0, str(ROOT_DIR))
from src.normalizers import EnglishTextNormalizer
from src.evaluate_utils import isd
from src.post_processer import remove_longest_repeating_words

# %%
target_folder = ROOT_DIR / 'data/result/Thonburian-whisper-deepbrain-lang' / 'th_Oppday_Q2_2023_IP_interfama'
label_dir = target_folder / 'Groundtruth.csv'
th_result_dir = target_folder / 'th_result.csv'
en_result_dir = target_folder / 'en_result.csv'
model = word_vector.WordVector(model_name="thai2fit_wv").get_model() # load thai2fit_wv from pythainlp

# %%
label_df = pd.read_csv(str(label_dir))
th_result_df = pd.read_csv(str(th_result_dir)) 
en_result_df = pd.read_csv(str(en_result_dir))

# %%
merge_result_df = pd.concat(
    [th_result_df, en_result_df],
    axis=0
)
merge_result_df.shape
# Out:
# (888, 3)

# %%
" ".strip()
# Out:
# ''

# %%
EXCEPTION_WORDS = {'ใน', 'ประเทศเนี่ยโรง'}

# %%
def evaluate_text(text: str, window_length: int=3, threshold: float=0.3) -> (bool ,List[str]):
    words = deepcut.tokenize(text)
    vectors = []
    # incorrect_words = []
    cossim_list = []
    is_correct = True
    for n, word in enumerate(words):
        # If word not present in tokenizer it might be 
        # jargon or incorrect word
        if word.strip() != "" and not word in EXCEPTION_WORDS:
            try:
                vectors.append(model[word])
            except KeyError as key_error:
                if word in str(key_error):
                    is_correct = False
                    print(f"incorrect words {word}")

    if len(vectors) < 2:
        return True, 1.0
    if window_length >= len(vectors):
        cosine_sim = cosine_similarity(vectors)
        cosine_sim = np.mean(np.mean(cosine_sim))
        print(cosine_sim)
    
    else:
        start = 0
        end = window_length 
        while end <= len(vectors):
            window = vectors[start:end]
            cosine_sim = cosine_similarity(window)
            cosine_sim = np.mean(np.mean(cosine_sim))
            cossim_list.append(cosine_sim)
            start = end
            end = start + window_length
        cosine_sim = np.mean(cossim_list)
    # print(words)
    # print(f"for {word_chunk}: cosine_similarity: {cossim_list}")   
    print(f"cosine_similarity: {cosine_sim}")
    if cosine_sim < threshold:
        print(words)
        is_correct = False
        
    return is_correct, cosine_sim

# %%
merge_result_df['is_correct'] = merge_result_df['text'].apply(evaluate_text)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 0.68216884
# cosine_similarity: 0.6821688413619995
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.3707128167152405
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.4303341805934906
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Auxility
# incorrect words Day
# cosine_similarity: 0.4031587839126587
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.38849517703056335
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ไทม่าส์
# cosine_similarity: 0.41859614849090576
# 2/2 [==============================] - 0s 4ms/step
# incorrect words บริษัท Interfarm
# cosine_similarity: 0.431443452835083
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.42583149671554565
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.40232759714126587
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.40667060017585754
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3961417078971863
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ทรัลสุขภาพ
# cosine_similarity: 0.40245503187179565
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.47153547406196594
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3950575590133667
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40736478567123413
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.43126532435417175
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4266875684261322
# 3/3 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4041251242160797
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.42911002039909363
# 1/1 [==============================] - 0s 15ms/step
# incorrect words อนุมัติธรรม
# cosine_similarity: 0.4242708384990692
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41966065764427185
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.45447051525115967
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3958281874656677
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เจินดาลิก
# incorrect words Phenocytical
# incorrect words เจินดาลิก
# cosine_similarity: 0.44075432419776917
# 2/2 [==============================] - 0s 3ms/step
# incorrect words สุทิศ
# cosine_similarity: 0.4844559133052826
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Cost
# incorrect words Based
# incorrect words Surgical
# cosine_similarity: 0.3874509930610657
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.46152421832084656
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ยานะ
# incorrect words ฟูจินาเทศักดิ์
# cosine_similarity: 0.3743026554584503
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41543710231781006
# 2/2 [==============================] - 0s 4ms/step
# incorrect words คอร์สเมสิทธิพล
# cosine_similarity: 0.35396650433540344
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Healthy
# cosine_similarity: 0.4487799108028412
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Food
# incorrect words Healthy
# incorrect words Drink
# incorrect words Healthy
# incorrect words Snack
# 1.0
# cosine_similarity: 1.0
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Personal
# incorrect words Care
# cosine_similarity: 0.4757986068725586
# 1/1 [==============================] - 0s 14ms/step
# incorrect words สโคป
# cosine_similarity: 0.41320788860321045
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4437698423862457
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4046767055988312
# 2/2 [==============================] - 0s 3ms/step
# incorrect words แตกต่อ
# cosine_similarity: 0.4043961465358734
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.36294347047805786
# 2/2 [==============================] - 0s 4ms/step
# incorrect words อุ๊ย
# cosine_similarity: 0.46786609292030334
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3903357982635498
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43038398027420044
# 2/2 [==============================] - 0s 3ms/step
# incorrect words อักเสรีฟังก์
# cosine_similarity: 0.43590644001960754
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.45155686140060425
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สัดย่อย
# incorrect words Modern
# incorrect words Smart
# cosine_similarity: 0.41450586915016174
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Inter
# cosine_similarity: 0.4102798104286194
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Sarma
# incorrect words ธยา
# cosine_similarity: 0.4217139482498169
# 2/2 [==============================] - 0s 5ms/step
# incorrect words กรรมรถ
# incorrect words ซิงเหล็ก
# cosine_similarity: 0.40090516209602356
# 2/2 [==============================] - 0s 3ms/step
# incorrect words รถไขมัน
# incorrect words ฟอลลิน
# cosine_similarity: 0.41191381216049194
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Sensing
# incorrect words เม่งง่วง
# incorrect words AlloTap
# cosine_similarity: 0.4252099394798279
# 2/2 [==============================] - 0s 3ms/step
# incorrect words เม่งง่วง
# cosine_similarity: 0.4233439266681671
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เนี้ย
# cosine_similarity: 0.42926907539367676
# 2/2 [==============================] - 0s 3ms/step
# incorrect words เฟลิร์นนะ
# cosine_similarity: 0.4359576404094696
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.46723830699920654
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3839735984802246
# 2/2 [==============================] - 0s 4ms/step
# incorrect words OTC
# cosine_similarity: 0.41545310616493225
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ไหร่
# cosine_similarity: 0.41754797101020813
# 1/1 [==============================] - 0s 23ms/step
# incorrect words ล่าพลาเนี่ย
# cosine_similarity: 0.43520987033843994
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3818560242652893
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# incorrect words คุ้นควบ
# 0.3913287
# cosine_similarity: 0.39132869243621826
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4031902253627777
# 2/2 [==============================] - 0s 5ms/step
# incorrect words ทธยา
# cosine_similarity: 0.39536574482917786
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ญาตา
# cosine_similarity: 0.4216154217720032
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4108075201511383
# 1/1 [==============================] - 0s 14ms/step
# incorrect words เมืองไทย
# cosine_similarity: 0.4028412997722626
# 1/1 [==============================] - 0s 18ms/step
# cosine_similarity: 0.4099745750427246
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4087411165237427
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ยุทยา
# cosine_similarity: 0.4117879271507263
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43680697679519653
# 1/1 [==============================] - 0s 14ms/step
# incorrect words เอ้า
# 0.64782965
# cosine_similarity: 0.6478296518325806
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42208123207092285
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เพวา
# cosine_similarity: 0.4684295356273651
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ศักยาดับ
# incorrect words ดุโกวิสลาเอนะ
# 0.55564696
# cosine_similarity: 0.5556469559669495
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ลิก
# incorrect words ยาเจนลิก
# cosine_similarity: 0.4073317050933838
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.38291752338409424
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3927522301673889
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.45638713240623474
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ยาตา
# cosine_similarity: 0.4049959182739258
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4136864244937897
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3970024585723877
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.5562623143196106
# 1/1 [==============================] - 0s 14ms/step
# 0.36880332
# cosine_similarity: 0.36880332231521606
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.6491137146949768
# 1/1 [==============================] - 0s 17ms/step
# cosine_similarity: 0.40733498334884644
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.43201127648353577
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4066397249698639
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.46430957317352295
# 1/1 [==============================] - 0s 15ms/step
# incorrect words PDF
# cosine_similarity: 0.36643484234809875
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42741212248802185
# 2/2 [==============================] - 0s 4ms/step
# incorrect words บรรทองการ
# cosine_similarity: 0.37955209612846375
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ประเยศ
# cosine_similarity: 0.4075038433074951
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ปุ๊บ
# cosine_similarity: 0.41271013021469116
# 2/2 [==============================] - 0s 4ms/step
# incorrect words อุณหภัทร
# incorrect words ออย่อเนี่ย
# cosine_similarity: 0.4372671842575073
# 2/2 [==============================] - 0s 3ms/step
# incorrect words อาจารย์ปวด
# cosine_similarity: 0.42302587628364563
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.37171652913093567
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ไขวัตถ์
# cosine_similarity: 0.3644280731678009
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ยินโฆษณา
# cosine_similarity: 0.42173901200294495
# 1/1 [==============================] - 0s 18ms/step
# cosine_similarity: 0.41351890563964844
# 1/1 [==============================] - 0s 19ms/step
# cosine_similarity: 0.43127870559692383
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40357667207717896
# 1/1 [==============================] - 0s 16ms/step
# incorrect words รั่ง
# cosine_similarity: 0.39174073934555054
# 2/2 [==============================] - 0s 5ms/step
# incorrect words ปวดก้าวเนื้อ
# cosine_similarity: 0.4765065312385559
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3757939040660858
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.38821643590927124
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.47505393624305725
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โบริเวิร์น
# incorrect words เทรด
# cosine_similarity: 0.42221853137016296
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3953832983970642
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.38959813117980957
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4241274297237396
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3902057707309723
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.3755798935890198
# 2/2 [==============================] - 0s 4ms/step
# incorrect words โปรเบิร์ติก
# cosine_similarity: 0.4055386483669281
# 1/1 [==============================] - 0s 15ms/step
# incorrect words อินเตอรี่
# 0.64782965
# cosine_similarity: 0.6478296518325806
# 1/1 [==============================] - 0s 16ms/step
# incorrect words Student
# cosine_similarity: 0.42437201738357544
# 1/1 [==============================] - 0s 15ms/step
# incorrect words แม่นแคพพิยายัน
# incorrect words อินพอสกับ
# 2/2 [==============================] - 0s 4ms/step
# incorrect words นูเท้า
# incorrect words ซูลิโคลด์
# incorrect words ผลัดเมืองทองโลก
# cosine_similarity: 0.41023239493370056
# 2/2 [==============================] - 0s 7ms/step
# incorrect words  ฟรีโบล
# cosine_similarity: 0.41522884368896484
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4461483955383301
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โอแบค
# cosine_similarity: 0.40713736414909363
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.39944204688072205
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โปรไกโอติก
# cosine_similarity: 0.39686131477355957
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4495336413383484
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4070265293121338
# 2/2 [==============================] - 0s 6ms/step
# incorrect words ล่อเล่น
# cosine_similarity: 0.38497257232666016
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3955233693122864
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43785974383354187
# 2/2 [==============================] - 0s 4ms/step
# incorrect words คุณโฟกัส
# cosine_similarity: 0.41289663314819336
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42591530084609985
# 1/1 [==============================] - 0s 15ms/step
# 0.51808333
# cosine_similarity: 0.5180833339691162
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.48900747299194336
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.480177640914917
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3838028907775879
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ศักดิ์สกรเนี่ย
# cosine_similarity: 0.44859105348587036
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40216121077537537
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เครดิตสโลวัตต์
# cosine_similarity: 0.4074998199939728
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4360444247722626
# 1/1 [==============================] - 0s 15ms/step
# incorrect words สำปะเลย
# 0.43739858
# cosine_similarity: 0.4373985826969147
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โปรเกติก
# cosine_similarity: 0.43487977981567383
# 2/2 [==============================] - 0s 4ms/step
# incorrect words บรรพบุรังนะ
# incorrect words โปรเกติก
# cosine_similarity: 0.4244081974029541
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ซ่อนเลน
# cosine_similarity: 0.447914183139801
# 2/2 [==============================] - 0s 4ms/step
# incorrect words TSO
# incorrect words มูส ยูมูส
# cosine_similarity: 0.4572644829750061
# 1/1 [==============================] - 0s 15ms/step
# incorrect words You
# incorrect words Tube
# incorrect words Test
# cosine_similarity: 0.41227081418037415
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40694549679756165
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41377702355384827
# 1/1 [==============================] - 0s 15ms/step
# incorrect words เอายอ
# cosine_similarity: 0.44736891984939575
# 1/1 [==============================] - 0s 16ms/step
# incorrect words คบจบ
# cosine_similarity: 0.42030268907546997
# 2/2 [==============================] - 0s 5ms/step
# incorrect words Policies
# cosine_similarity: 0.40068089962005615
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41803231835365295
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.36228302121162415
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4139094948768616
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4330310821533203
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Paper
# incorrect words Application
# cosine_similarity: 0.4723273515701294
# 2/2 [==============================] - 0s 3ms/step
# incorrect words แนวโน้ต
# cosine_similarity: 0.4398665428161621
# 2/2 [==============================] - 0s 5ms/step
# incorrect words โปรเกติกเนี่ย
# cosine_similarity: 0.42041194438934326
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4652612805366516
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40454912185668945
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ฉับฟัน
# incorrect words อ่อนโยง
# cosine_similarity: 0.374939501285553
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.38190633058547974
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4073084890842438
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.390543669462204
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3896552324295044
# 3/3 [==============================] - 0s 3ms/step
# cosine_similarity: 0.43440118432044983
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40527477860450745
# 2/2 [==============================] - 0s 14ms/step
# incorrect words ยินยาว
# cosine_similarity: 0.4152774512767792
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.42659759521484375
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41995540261268616
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.4188329875469208
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4405568838119507
# 2/2 [==============================] - 0s 6ms/step
# cosine_similarity: 0.43994468450546265
# 2/2 [==============================] - 0s 5ms/step
# incorrect words สัจเจวี
# incorrect words Interformer
# incorrect words Thai
# incorrect words Union
# cosine_similarity: 0.48995718359947205
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ไทยอินเตอร์ฟาร์ม่า
# cosine_similarity: 0.3864520490169525
# 2/2 [==============================] - 0s 3ms/step
# incorrect words อินเตอร์ฟาร์ม่า
# cosine_similarity: 0.4423896372318268
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4454638957977295
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.5176655054092407
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.371762752532959
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43845081329345703
# 1/1 [==============================] - 0s 15ms/step
# incorrect words DSA
# incorrect words เนอะ
# cosine_similarity: 0.4673044979572296
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4262101650238037
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ลูกทาน
# cosine_similarity: 0.39320188760757446
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.419408917427063
# 1/1 [==============================] - 0s 15ms/step
# incorrect words พันธมณ์
# incorrect words DSA
# cosine_similarity: 0.3959551453590393
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4843869209289551
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4044802486896515
# 2/2 [==============================] - 0s 4ms/step
# incorrect words DHA
# cosine_similarity: 0.3942399024963379
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Position
# cosine_similarity: 0.4031749963760376
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ยุทธยาเนี่ย
# cosine_similarity: 0.43195411562919617
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42885392904281616
# 2/2 [==============================] - 0s 4ms/step
# incorrect words EU
# incorrect words Standard
# cosine_similarity: 0.4365411698818207
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Standard
# cosine_similarity: 0.3927202522754669
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41522112488746643
# 2/2 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4047270119190216
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4194242060184479
# 1/1 [==============================] - 0s 19ms/step
# cosine_similarity: 0.4087041914463043
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ประจก
# cosine_similarity: 0.3989715576171875
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.3958839774131775
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42290225625038147
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42660316824913025
# 3/3 [==============================] - 0s 3ms/step
# incorrect words ทานเฟอร์
# cosine_similarity: 0.41418132185935974
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4721001088619232
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4222365915775299
# 1/1 [==============================] - 0s 15ms/step
# incorrect words หม่อมยาดม
# cosine_similarity: 0.4383079409599304
# 1/1 [==============================] - 0s 16ms/step
# incorrect words อมสมุนไพร
# cosine_similarity: 0.43539249897003174
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โรงงานสมุด
# cosine_similarity: 0.4119685888290405
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.41119384765625
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สมุทรไทย
# cosine_similarity: 0.42619383335113525
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.38324666023254395
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40783312916755676
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.37783342599868774
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41104039549827576
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3385409116744995
# 1/1 [==============================] - 0s 21ms/step
# cosine_similarity: 0.41577669978141785
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ถุงยา
# incorrect words น้องหมา
# incorrect words น้องแมว
# 18/18 [==============================] - 0s 4ms/step
# incorrect words อ๋อ
# incorrect words  โอเค
# cosine_similarity: 1.0
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.33418890833854675
# 1/1 [==============================] - 0s 23ms/step
# cosine_similarity: 0.42777156829833984
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สมุดเวทสมทาง
# incorrect words น้องหมากน้องแมวเนี่ย
# 0.6441076
# cosine_similarity: 0.6441075801849365
# 2/2 [==============================] - 0s 3ms/step
# incorrect words รกร่าง
# cosine_similarity: 0.39185023307800293
# 2/2 [==============================] - 0s 5ms/step
# incorrect words เว็บ
# incorrect words โพดับ
# cosine_similarity: 0.42858216166496277
# 2/2 [==============================] - 0s 3ms/step
# incorrect words P
# incorrect words Civative
# incorrect words Free
# incorrect words Gift
# incorrect words Gluten
# incorrect words Free
# cosine_similarity: 0.6347670555114746
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Grain
# incorrect words Free
# incorrect words P
# incorrect words Bertig
# incorrect words Omega
# cosine_similarity: 0.4326867461204529
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4227108955383301
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4597488045692444
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4685018062591553
# 3/3 [==============================] - 0s 3ms/step
# incorrect words บู
# cosine_similarity: 0.44504237174987793
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4162949323654175
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Interformer
# 0.6567427
# cosine_similarity: 0.6567426919937134
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ออมเกณฑ์
# incorrect words อ่ะ
# cosine_similarity: 0.42370834946632385
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.36258578300476074
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.395747572183609
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พกวงจร
# cosine_similarity: 0.413116455078125
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ต้นน้ำยัน
# incorrect words น้ำเนี่ย
# cosine_similarity: 0.4428263008594513
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3815441131591797
# 2/2 [==============================] - 0s 3ms/step
# incorrect words วิทยาเนี่ย
# cosine_similarity: 0.41067588329315186
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.40442129969596863
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.383926659822464
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.46790826320648193
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Modern
# incorrect words Farmer
# cosine_similarity: 0.4185445308685303
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4200040102005005
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40646588802337646
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.47475388646125793
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40164658427238464
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4029197692871094
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41334986686706543
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ยุทยา
# cosine_similarity: 0.3859689235687256
# 1/1 [==============================] - 0s 15ms/step
# incorrect words Circular
# cosine_similarity: 0.42914146184921265
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.43478330969810486
# 1/1 [==============================] - 0s 15ms/step
# incorrect words พาราแบบ
# cosine_similarity: 0.37928980588912964
# 2/2 [==============================] - 0s 6ms/step
# cosine_similarity: 0.4395412504673004
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4331371784210205
# 2/2 [==============================] - 0s 3ms/step
# incorrect words น้ำเนี่ย
# cosine_similarity: 0.4482044279575348
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ฟอร์มเมอร์ซีน
# cosine_similarity: 0.43272849917411804
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.39240649342536926
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4293825924396515
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40000423789024353
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4698946475982666
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4195009469985962
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.48826131224632263
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.421871542930603
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ออยอย
# incorrect words เกลือบ
# cosine_similarity: 0.346136212348938
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4219590723514557
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4254762530326843
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.42941492795944214
# 1/1 [==============================] - 0s 23ms/step
# incorrect words จันทร์ยา
# cosine_similarity: 0.4647865295410156
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3981056213378906
# 1/1 [==============================] - 0s 14ms/step
# 0.52992237
# cosine_similarity: 0.529922366142273
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.44643667340278625
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4307037889957428
# 2/2 [==============================] - 0s 4ms/step
# incorrect words OR
# cosine_similarity: 0.36006951332092285
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.45599403977394104
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ตุลาคนะ
# cosine_similarity: 0.3877308964729309
# 2/2 [==============================] - 0s 5ms/step
# incorrect words สัดธารศักดิ์ชิพ
# cosine_similarity: 0.4578295648097992
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.3798849284648895
# 2/2 [==============================] - 0s 3ms/step
# incorrect words นิรุภัย
# cosine_similarity: 0.3984260559082031
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4318951666355133
# 1/1 [==============================] - 0s 15ms/step
# incorrect words หนองแทน
# cosine_similarity: 0.42762333154678345
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.43997544050216675
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.42745402455329895
# 1/1 [==============================] - 0s 15ms/step
# incorrect words วิชาใต้
# cosine_similarity: 0.4292927086353302
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ล้มลือ
# cosine_similarity: 0.40196701884269714
# 2/2 [==============================] - 0s 3ms/step
# incorrect words พยาบาลนครทัศน์
# incorrect words นครทัศน์
# incorrect words นครศรีธรรมดา
# cosine_similarity: 0.4350869357585907
# 1/1 [==============================] - 0s 15ms/step
# incorrect words รีโน
# cosine_similarity: 0.3874228596687317
# 2/2 [==============================] - 0s 3ms/step
# incorrect words นครศรีธรรมดา
# incorrect words เจ๋
# cosine_similarity: 0.437808632850647
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4259837865829468
# 2/2 [==============================] - 0s 4ms/step
# incorrect words รีโน
# incorrect words เวทเสร็จ
# cosine_similarity: 0.4223574995994568
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4604288935661316
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.37900635600090027
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41366061568260193
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3888571262359619
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.38532862067222595
# 1/1 [==============================] - 0s 14ms/step
# incorrect words โซบิด
# cosine_similarity: 0.4883240759372711
# 1/1 [==============================] - 0s 14ms/step
# incorrect words เต๋อ
# incorrect words อัพ
# cosine_similarity: 0.40615516901016235
# 1/1 [==============================] - 0s 17ms/step
# incorrect words ธอมมาสเตอร์ สูร
# 0.4867642
# cosine_similarity: 0.48676419258117676
# 2/2 [==============================] - 0s 4ms/step
# incorrect words หูน
# incorrect words เอฟเฟติก
# cosine_similarity: 0.40834760665893555
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ศูนย์สุขภาพ
# cosine_similarity: 0.3993515372276306
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Beauty
# incorrect words Center
# cosine_similarity: 0.5513942241668701
# 1/1 [==============================] - 0s 14ms/step
# 0.6567427
# cosine_similarity: 0.6567426919937134
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4610805809497833
# 2/2 [==============================] - 0s 3ms/step
# incorrect words SET
# incorrect words AWARDS
# incorrect words เงี้ย
# incorrect words อินโดรเวที
# cosine_similarity: 0.4886794686317444
# 1/1 [==============================] - 0s 15ms/step
# 0.4051695
# cosine_similarity: 0.4051694869995117
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3959704637527466
# 1/1 [==============================] - 0s 14ms/step
# incorrect words โปรเกติก
# cosine_similarity: 0.4700723886489868
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4419575035572052
# 2/2 [==============================] - 0s 3ms/step
# incorrect words KGI
# cosine_similarity: 0.4311162531375885
# 2/2 [==============================] - 0s 3ms/step
# incorrect words หลักแผน
# cosine_similarity: 0.3793236017227173
# 2/2 [==============================] - 0s 3ms/step
# incorrect words บริษัทแอลกอฮอล์รี่
# cosine_similarity: 0.5467589497566223
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.36596742272377014
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4008519947528839
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4872548282146454
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4014372229576111
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42273175716400146
# 2/2 [==============================] - 0s 4ms/step
# incorrect words รีวิว
# incorrect words R&
# incorrect words B
# cosine_similarity: 0.46461614966392517
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เนอะ
# cosine_similarity: 0.429080605506897
# 1/1 [==============================] - 0s 15ms/step
# 0.6567427
# cosine_similarity: 0.6567426919937134
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4022749662399292
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.438632071018219
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4719506800174713
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4325454533100128
# 2/2 [==============================] - 0s 4ms/step
# incorrect words วิวสิทธิ์
# cosine_similarity: 0.4074363708496094
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เนเจอ
# cosine_similarity: 0.40938007831573486
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Developer
# cosine_similarity: 0.45559340715408325
# 1/1 [==============================] - 0s 22ms/step
# cosine_similarity: 0.4111042022705078
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.45473513007164
# 2/2 [==============================] - 0s 4ms/step
# incorrect words บริษัทธรรมดา
# cosine_similarity: 0.4595239758491516
# 1/1 [==============================] - 0s 16ms/step
# incorrect words ไฟใต้
# incorrect words ยุโนโลยีเอเชียเนี่ย
# 2/2 [==============================] - 0s 3ms/step
# incorrect words รีเควส
# incorrect words อินเตอร์ฟาร์ม่า
# cosine_similarity: 0.47632622718811035
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4287961721420288
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4566349685192108
# 1/1 [==============================] - 0s 15ms/step
# incorrect words 2038
# cosine_similarity: 0.4136965870857239
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4224604368209839
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4182574152946472
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4026884138584137
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4434530436992645
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.39978787302970886
# 2/2 [==============================] - 0s 3ms/step
# incorrect words วัฏกรรม
# cosine_similarity: 0.41129109263420105
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.3397570252418518
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3841153085231781
# 1/1 [==============================] - 0s 15ms/step
# 0.44228846
# cosine_similarity: 0.44228845834732056
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41776153445243835
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41866588592529297
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41525715589523315
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4033049941062927
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43678510189056396
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.44416335225105286
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.43236321210861206
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4177572727203369
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4280450940132141
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4516858756542206
# 1/1 [==============================] - 0s 13ms/step
# 0.40001902
# cosine_similarity: 0.4000190198421478
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.41161105036735535
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4133673310279846
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.43304014205932617
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.40594804286956787
# 2/2 [==============================] - 0s 4ms/step
# incorrect words โปลแบ็กซ์
# incorrect words โปลแบ็กซ์
# cosine_similarity: 0.41220349073410034
# 2/2 [==============================] - 0s 4ms/step
# incorrect words โปลแบ็กซ์
# incorrect words เทรด
# cosine_similarity: 0.3797307312488556
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4641169011592865
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.43562373518943787
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Intentional
# incorrect words Asset
# cosine_similarity: 0.3966968059539795
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3848406970500946
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.39991047978401184
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.45357903838157654
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.3960011899471283
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.44016528129577637
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43436190485954285
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4156462252140045
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ไหร่
# cosine_similarity: 0.3937687277793884
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4599432647228241
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.5105976462364197
# 1/1 [==============================] - 0s 13ms/step
# incorrect words EU
# incorrect words Standout
# cosine_similarity: 0.39614784717559814
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.37806057929992676
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.409077525138855
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.43872320652008057
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4433525502681732
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.41762426495552063
# 1/1 [==============================] - 0s 14ms/step
# 0.47327074
# cosine_similarity: 0.4732707440853119
# 1/1 [==============================] - 0s 14ms/step
# 0.4084001
# cosine_similarity: 0.4084000885486603
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.41848886013031006
# 2/2 [==============================] - 0s 3ms/step
# incorrect words แบกเนี่ย
# cosine_similarity: 0.4335756301879883
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.40241605043411255
# 1/1 [==============================] - 0s 14ms/step
# incorrect words สนานา
# cosine_similarity: 0.5689554810523987
# 1/1 [==============================] - 0s 13ms/step
# 0.45139372
# cosine_similarity: 0.451393723487854
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42262792587280273
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41425180435180664
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4016459882259369
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4032011330127716
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.40756773948669434
# 2/2 [==============================] - 0s 3ms/step
# incorrect words บริษัท Inubix
# incorrect words ปตท.
# cosine_similarity: 0.38947975635528564
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4034309983253479
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.37208616733551025
# 2/2 [==============================] - 0s 7ms/step
# cosine_similarity: 0.4213855564594269
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4106653332710266
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4335780739784241
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ท็อปไลน์
# cosine_similarity: 0.4046863317489624
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4437846839427948
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.45295068621635437
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4046318233013153
# 2/2 [==============================] - 0s 3ms/step
# incorrect words เจ้าผู้
# cosine_similarity: 0.44644662737846375
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.45430588722229004
# 2/2 [==============================] - 0s 3ms/step
# incorrect words สี่เนี่ย
# cosine_similarity: 0.5312997102737427
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43480968475341797
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4796733260154724
# 1/1 [==============================] - 0s 17ms/step
# cosine_similarity: 0.36738693714141846
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 0.45493317
# cosine_similarity: 0.45493316650390625
# 1/1 [==============================] - 0s 14ms/step
# 0.53096545
# cosine_similarity: 0.5309654474258423
# 1/1 [==============================] - 0s 14ms/step
# 0.45493317
# cosine_similarity: 0.45493316650390625
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4119414687156677
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42407429218292236
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4385213851928711
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4346838593482971
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4650079011917114
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3793865740299225
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4126916825771332
# 2/2 [==============================] - 0s 5ms/step
# incorrect words โรงพยาบาลเนี่ย
# cosine_similarity: 0.3927944302558899
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3851397931575775
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3962332010269165
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.40118521451950073
# 1/1 [==============================] - 0s 14ms/step
# 0.621386
# cosine_similarity: 0.6213859915733337
# 1/1 [==============================] - 0s 15ms/step
# incorrect words เงี้ย
# cosine_similarity: 0.40790241956710815
# 1/1 [==============================] - 0s 15ms/step
# incorrect words รายไตรนะ
# cosine_similarity: 0.3986984193325043
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ฟิตเบน
# cosine_similarity: 0.46135908365249634
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.422777384519577
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พยาบาลเนี่ย
# cosine_similarity: 0.394176721572876
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Cost
# incorrect words Profit
# cosine_similarity: 0.452710896730423
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Cost
# incorrect words Profit
# cosine_similarity: 0.40957504510879517
# 1/1 [==============================] - 0s 17ms/step
# 0.48649126
# cosine_similarity: 0.48649126291275024
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4598599374294281
# 2/2 [==============================] - 0s 4ms/step
# incorrect words covid
# cosine_similarity: 0.41913941502571106
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.4210015535354614
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4342195391654968
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.412838876247406
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.41295427083969116
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4158661663532257
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4704754054546356
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4246284067630768
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4292439818382263
# 2/2 [==============================] - 0s 5ms/step
# incorrect words Operating
# cosine_similarity: 0.4466547966003418
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Expense
# incorrect words Profit
# cosine_similarity: 0.4580209255218506
# 2/2 [==============================] - 0s 3ms/step
# incorrect words เงี้ย
# cosine_similarity: 0.4305723309516907
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4567335546016693
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Feeling
# incorrect words Administrative
# incorrect words Expected
# cosine_similarity: 0.42417439818382263
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4408470094203949
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ไตรมา
# incorrect words สนึง
# cosine_similarity: 0.3934468626976013
# 1/1 [==============================] - 0s 23ms/step
# 0.6567427
# cosine_similarity: 0.6567426919937134
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.45223116874694824
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.49541038274765015
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โปรฟิกซ์
# cosine_similarity: 0.40582820773124695
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.44671499729156494
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.391487181186676
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42125585675239563
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.44568729400634766
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Opposite
# incorrect words Day
# cosine_similarity: 0.39397886395454407
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.39845943450927734
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Q&A
# cosine_similarity: 0.4316338896751404
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.42591390013694763
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41063061356544495
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ขยา
# cosine_similarity: 0.428795725107193
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ดร.ฟอร์มา
# incorrect words  โอคอมเซเว่น
# cosine_similarity: 0.4323021173477173
# 1/1 [==============================] - 0s 20ms/step
# cosine_similarity: 0.46659478545188904
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.41899168491363525
# 1/1 [==============================] - 0s 13ms/step
# 0.4512319
# cosine_similarity: 0.4512318968772888
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3946138024330139
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.3661719560623169
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41008028388023376
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Gain
# incorrect words Market
# ...
# 1/1 [==============================] - 0s 16ms/step
# cosine_similarity: 0.4124418795108795
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Translator
# cosine_similarity: 0.40007928013801575
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เดลล่าพลาสเนี่ย
# cosine_similarity: 0.4254656136035919
# 1/1 [==============================] - 0s 14ms/step
# 0.5418233
# cosine_similarity: 0.5418233275413513
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ทธิญา
# cosine_similarity: 0.4179249107837677
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43401727080345154
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43213486671447754
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.38881587982177734
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พาเซตตี้
# cosine_similarity: 0.41410139203071594
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43086138367652893
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41049548983573914
# 1/1 [==============================] - 0s 17ms/step
# incorrect words เนี่ยน
# incorrect words  จับทาง
# 0.35605434
# cosine_similarity: 0.3560543358325958
# 2/2 [==============================] - 0s 5ms/step
# incorrect words ทดทอบ
# incorrect words บริษัทอิงโดนิก
# cosine_similarity: 0.4087594151496887
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4551520347595215
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.4178098142147064
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4014081060886383
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3974108099937439
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4325515329837799
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ล็อตเนี่ย
# cosine_similarity: 0.4110943675041199
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4120192229747772
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4444485306739807
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ทายูเลียน
# cosine_similarity: 0.43783605098724365
# 1/1 [==============================] - 0s 14ms/step
# incorrect words พาวิคิโนบิกเนี่ย
# cosine_similarity: 0.4116542637348175
# 1/1 [==============================] - 0s 16ms/step
# incorrect words เฉลี่ยรักษ์
# cosine_similarity: 0.4516580402851105
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4326196610927582
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4330768585205078
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ล่าพลา
# cosine_similarity: 0.3761109411716461
# 1/1 [==============================] - 0s 17ms/step
# cosine_similarity: 0.40219321846961975
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4503650665283203
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40328872203826904
# 1/1 [==============================] - 0s 17ms/step
# cosine_similarity: 0.5742818713188171
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เภสัชนะ
# incorrect words เภสัชบาง
# cosine_similarity: 0.4353254735469818
# 2/2 [==============================] - 0s 5ms/step
# incorrect words เภสัชนะ
# cosine_similarity: 0.4192756116390228
# 2/2 [==============================] - 0s 3ms/step
# incorrect words สำทัญ
# cosine_similarity: 0.4097958505153656
# 1/1 [==============================] - 0s 15ms/step
# incorrect words ทีเอชดี
# cosine_similarity: 0.49139559268951416
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4000886380672455
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ศาสนว
# incorrect words นวิทยาศาสตร์
# 0.41637933
# cosine_similarity: 0.41637933254241943
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Bidder
# incorrect words  pack
# cosine_similarity: 0.4173179864883423
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.41511836647987366
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.41651642322540283
# 1/1 [==============================] - 0s 15ms/step
# 0.44016528
# cosine_similarity: 0.44016528129577637
# 2/2 [==============================] - 0s 6ms/step
# cosine_similarity: 0.4289178252220154
# 2/2 [==============================] - 0s 4ms/step
# incorrect words อ่ะ
# incorrect words Business
# cosine_similarity: 0.3881731927394867
# 1/1 [==============================] - 0s 19ms/step
# cosine_similarity: 0.45142531394958496
# 2/2 [==============================] - 0s 3ms/step
# incorrect words วิสเตอร์แพ็คเนี่ย
# cosine_similarity: 0.4465494751930237
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พลาสสิก
# incorrect words เงี้ย
# cosine_similarity: 0.43065541982650757
# 1/1 [==============================] - 0s 18ms/step
# cosine_similarity: 0.47080549597740173
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.43660080432891846
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3990275263786316
# 1/1 [==============================] - 0s 14ms/step
# incorrect words โรยา
# cosine_similarity: 0.43811532855033875
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สุน
# cosine_similarity: 0.43898239731788635
# 1/1 [==============================] - 0s 14ms/step
# 0.44097772
# cosine_similarity: 0.44097772240638733
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4360036253929138
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4461498260498047
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.44568324089050293
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.3839913308620453
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.3897796869277954
# 2/2 [==============================] - 0s 4ms/step
# incorrect words ลองมอง
# cosine_similarity: 0.38026660680770874
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41207271814346313
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4409104585647583
# 2/2 [==============================] - 0s 3ms/step
# incorrect words อยู่แล้ว
# cosine_similarity: 0.4087505340576172
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3905375897884369
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.4300737679004669
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.39655590057373047
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.40393558144569397
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ซีลิต้า
# cosine_similarity: 0.4629802107810974
# 1/1 [==============================] - 0s 14ms/step
# incorrect words แก้เปลี่ยน
# cosine_similarity: 0.44097650051116943
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.45208078622817993
# 2/2 [==============================] - 0s 3ms/step
# incorrect words สิริวิตาเนี่ย
# incorrect words สิริวิตาคลาเซียม
# 0.49665922
# cosine_similarity: 0.49665921926498413
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สิริวิตาคลาเซียมเนี่ย
# cosine_similarity: 0.3760603964328766
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3998004198074341
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.43064752221107483
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4170687794685364
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41906991600990295
# 2/2 [==============================] - 0s 5ms/step
# incorrect words สัดร่วม
# cosine_similarity: 0.4056990444660187
# 2/2 [==============================] - 0s 3ms/step
# incorrect words Interformer
# incorrect words Civita
# cosine_similarity: 0.4158233404159546
# 2/2 [==============================] - 0s 3ms/step
# incorrect words ลิซ่า
# cosine_similarity: 0.4518250524997711
# 2/2 [==============================] - 0s 4ms/step
# incorrect words DHA
# incorrect words ลิซ่า
# incorrect words DHA
# cosine_similarity: 0.38962626457214355
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42233407497406006
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4130202531814575
# 1/1 [==============================] - 0s 14ms/step
# incorrect words ลิซ่า
# incorrect words DHA
# cosine_similarity: 0.4011319577693939
# 1/1 [==============================] - 0s 16ms/step
# incorrect words TrueBow
# cosine_similarity: 0.42406758666038513
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Turbo
# incorrect words OTC
# incorrect words Consumer
# cosine_similarity: 0.4048653841018677
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4940732717514038
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4469604194164276
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พยาบาลก่อน
# cosine_similarity: 0.4712204933166504
# 2/2 [==============================] - 0s 3ms/step
# incorrect words เนี่ยการ
# cosine_similarity: 0.43450579047203064
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4707126319408417
# 2/2 [==============================] - 0s 5ms/step
# incorrect words ทูโบ
# cosine_similarity: 0.4377823770046234
# 2/2 [==============================] - 0s 3ms/step
# incorrect words โรงเชื้อ
# incorrect words นิก
# incorrect words คีนิก
# cosine_similarity: 0.37043872475624084
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3852810263633728
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42459607124328613
# 2/2 [==============================] - 0s 4ms/step
# incorrect words พยาบาลเนี่ย
# cosine_similarity: 0.4065629541873932
# 2/2 [==============================] - 0s 4ms/step
# incorrect words อ่ะ
# cosine_similarity: 0.4367401599884033
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.46377861499786377
# 2/2 [==============================] - 0s 4ms/step
# incorrect words โอ้จุด
# cosine_similarity: 0.38740772008895874
# 2/2 [==============================] - 0s 4ms/step
# incorrect words เคส
# incorrect words  เคส
# cosine_similarity: 0.4825614094734192
# 2/2 [==============================] - 0s 4ms/step
# incorrect words Pilot
# incorrect words Study
# cosine_similarity: 0.47311699390411377
# 2/2 [==============================] - 0s 4ms/step
# incorrect words บูบ
# incorrect words สเต็ป
# cosine_similarity: 0.3981083631515503
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41029417514801025
# 2/2 [==============================] - 0s 4ms/step
# incorrect words อินเตอร์ฟาร์ม่า
# cosine_similarity: 0.3562050461769104
# 1/1 [==============================] - 0s 17ms/step
# incorrect words พยาบาลกัน
# cosine_similarity: 0.39506879448890686
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.3922361731529236
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42670831084251404
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.43574872612953186
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4435236155986786
# 1/1 [==============================] - 0s 14ms/step
# cosine_similarity: 0.3886963129043579
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4152958393096924
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.44758495688438416
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.42165786027908325
# 2/2 [==============================] - 0s 4ms/step
# incorrect words แบคทีเรียท
# cosine_similarity: 0.41614532470703125
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.43056491017341614
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.3898235559463501
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4193781316280365
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4355940818786621
# 2/2 [==============================] - 0s 4ms/step
# incorrect words รูปราคา
# cosine_similarity: 0.40620914101600647
# 1/1 [==============================] - 0s 18ms/step
# cosine_similarity: 0.40810585021972656
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4528290629386902
# 1/1 [==============================] - 0s 13ms/step
# cosine_similarity: 0.4173229932785034
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.41375812888145447
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.41478994488716125
# 1/1 [==============================] - 0s 15ms/step
# incorrect words เทคออฟมัน
# cosine_similarity: 0.46757617592811584
# 1/1 [==============================] - 0s 14ms/step
# 0.4159176
# cosine_similarity: 0.41591760516166687
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.4372185170650482
# 2/2 [==============================] - 0s 4ms/step
# incorrect words โปรเบติก
# incorrect words โปรเบติก
# cosine_similarity: 0.3939897119998932
# 2/2 [==============================] - 0s 4ms/step
# incorrect words สเติร์ส
# cosine_similarity: 0.4038277566432953
# 1/1 [==============================] - 0s 15ms/step
# 0.53096545
# cosine_similarity: 0.5309654474258423
# 1/1 [==============================] - 0s 15ms/step
# incorrect words โลก็
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.5166526436805725
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.4446201026439667
# 1/1 [==============================] - 0s 15ms/step
# cosine_similarity: 0.5119433999061584
# 1/1 [==============================] - 0s 14ms/step
# 0.38976496
# cosine_similarity: 0.3897649645805359
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.41056549549102783
# 1/1 [==============================] - 0s 15ms/step
# 0.5711542
# cosine_similarity: 0.5711541771888733
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.423137903213501
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4174509346485138
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.4835456311702728
# 2/2 [==============================] - 0s 5ms/step
# incorrect words ซับซ้าย
# cosine_similarity: 0.42910072207450867
# 2/2 [==============================] - 0s 5ms/step
# cosine_similarity: 0.43246927857398987
# 2/2 [==============================] - 0s 3ms/step
# cosine_similarity: 0.42787081003189087
# 2/2 [==============================] - 0s 4ms/step
# cosine_similarity: 0.39480793476104736
# 1/1 [==============================] - 0s 25ms/step
# cosine_similarity: 0.46372127532958984
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Many
# cosine_similarity: 0.4837299883365631
# 1/1 [==============================] - 0s 15ms/step
# incorrect words Open
# 0.55559444
# cosine_similarity: 0.5555944442749023
# 1/1 [==============================] - 0s 13ms/step
# 0.57235396
# cosine_similarity: 0.5723539590835571
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Om
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Hello
# incorrect words Hello
# 1.0000001
# cosine_similarity: 1.0000001192092896
# 1/1 [==============================] - 0s 14ms/step
# incorrect words No
# 1/1 [==============================] - 0s 18ms/step
# incorrect words Oh
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Oh
# 1/1 [==============================] - 0s 19ms/step
# 0.6648856
# cosine_similarity: 0.6648855805397034
# 1/1 [==============================] - 0s 15ms/step
# incorrect words The
# incorrect words Crown
# 1/1 [==============================] - 0s 12ms/step
# incorrect words With
# incorrect words  you
# 1/1 [==============================] - 0s 14ms/step
# incorrect words The
# 1/1 [==============================] - 0s 14ms/step
# incorrect words Oh
# 0.48764953
# cosine_similarity: 0.487649530172348
# 1/1 [==============================] - 0s 15ms/step
# 0.6915606
# cosine_similarity: 0.6915606260299683

# %%
merge_result_df.to_csv("checked_result.csv")

# %%
incorrect = 'สวัสดีครับ'

# %%
evaluate_text(incorrect)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 0.68216884
# ['สวัสดี', 'ครับ']
# cosine_similarity: 0.6821688413619995
# (True, 0.68216884)
