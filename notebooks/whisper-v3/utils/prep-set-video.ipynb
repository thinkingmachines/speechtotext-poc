# %%
# # Download ong's data
# !gdown --id 1ZZJ23ejcMEsaLBkSbOZmlxXyhIVZqfJo

# # Download amm's data
# !gdown --id 1TRPRcDEyi6ogu8j4OE_d_ePJRxUw_X1m

# %%
from pathlib import Path
from itertools import chain
import re

import pysrt
import pandas as pd
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %%
ROOT_PATH = Path.cwd().parent / "data" / "Opp Day SRTs" 
(VIDEO_CHUNKS_PATH := ROOT_PATH / "chunks").mkdir(exist_ok=True)

# %%
fr_srts = list((ROOT_PATH / "Freelancer SRT").rglob("*.srt"))
capcut_srts = list((ROOT_PATH / "Capcut SRT").rglob("*.srt"))
vids = list((ROOT_PATH).rglob("*.mp4"))

# %%
def gen_srt_map(ls: list[Path], exist_dict: dict = {}) -> dict[str, Path]:
    def hard_mapping(s: str) -> str:
        s = Path(clean_logic(s)).stem.upper()
        mapping = {"interpharma": "IP"}
        return mapping.get(s.lower(), s)
        
        
    def clean_logic(s: str) -> str:
        s = re.sub("FL-", "", s)
        if " " in s:
            candidate = s.split(" ")[0]
            if candidate == "Opp":
                return re.search("[A-Z]{2,}", s).group(0)
            return candidate
        
        return s.split("-")[0]
        
    return exist_dict | {hard_mapping(clean_logic(l.name)): l for l in ls}

def gen_video_map(ls: list[Path]) -> dict[str, Path]:
    return {re.search("[A-Z]{2,}", l.name).group(0): l for l in ls}

def cut_video_into_chunks(symbol: str, srt_maps: dict, vid_maps: dict) -> list[str, Path]:
    sub_pth, vid_pth = srt_maps.get(symbol, None), vid_maps.get(symbol, None)
    
    if sub_pth is None or vid_pth is None:
        print("sub or vid is not exist", sub_pth, vid_pth)
        return

    subs = pysrt.open(sub_pth)
    
    metadata = []
    # Loop through the subtitles
    for i, sub in enumerate(subs):
        print(sub)
        # Get the start and end times of each subtitle
        start_time = sub.start.ordinal / 1000.0
        end_time = sub.end.ordinal / 1000.0

        # Use ffmpeg to cut the video for this subtitle
        target_pth = VIDEO_CHUNKS_PATH / f"{vid_pth.name}_{i:04d}.mp4"
        transcription = sub.text
        ffmpeg_extract_subclip(vid_pth, start_time, end_time, targetname=target_pth)
    
        metadata.append((symbol, target_pth, transcription))
        
    return metadata

# %%
srt_maps = gen_srt_map(capcut_srts)
srt_maps = gen_srt_map(fr_srts, srt_maps)

# %%
vid_maps = gen_video_map(vids)

# %%
print(srt_maps.keys())
print(vid_maps.keys())
# Out:
# dict_keys(['HENG', 'IP', 'THAIKOM', 'SPVI', 'BGRIMM', 'TRIPLEI', 'IRPC', 'THREL', 'GLOBAL', 'SAK', 'MUANGTHAI', 'PSH', 'ADVANC', 'TAN', 'NOBLE', 'PSH_REVISED', 'GC'])
# dict_keys(['PSH', 'ADVANC', 'TAN', 'BGRIM', 'TH', 'MINT', 'HENG', 'THREL', 'NOBLE', 'GC', 'ADB', 'SAK', 'THCOM', 'MTC', 'SAWAD', 'IRPC', 'III', 'SPVI'])

# %%
target_symbols = set(vid_maps.keys()).intersection(srt_maps.keys())
print(target_symbols)
# Out:
# {'GC', 'IRPC', 'NOBLE', 'TAN', 'SPVI', 'HENG', 'SAK', 'ADVANC', 'PSH', 'THREL'}

# %%
results = list(chain.from_iterable([cut_video_into_chunks(symbol, srt_maps, vid_maps) for symbol in target_symbols]))
# Out:
# 1
# 00:00:11,433 --> 00:00:12,666
# ค่ะ สวัสดีค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 2
# 00:00:14,000 --> 00:00:16,033
# ดิฉัน พรพิพล ต่อไพบูลย์ นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 3
# 00:00:16,200 --> 00:00:18,366
# ประธานเจ้าหน้าที่บริหารของบริษัท
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 4
# 00:00:18,366 --> 00:00:19,800
# โกลบอล คอนเนคชั่นส์ จํากัด มหาชน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 5
# 00:00:20,166 --> 00:00:20,966
# นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 6
# 00:00:21,300 --> 00:00:22,700
# มาพร้อมกับ คุณประวิชญา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 7
# 00:00:22,800 --> 00:00:23,766
# หรรษกุล นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 8
# 00:00:24,000 --> 00:00:26,433
# ที่ปรึกษาฝ่ายบัญชี และการเงินของเราค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 9
# 00:00:26,433 --> 00:00:27,233
# สวัสดีค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 10
# 00:00:27,800 --> 00:00:28,566
# วันนี้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 11
# 00:00:28,566 --> 00:00:30,866
# เรามาคุยในเรื่องของผลประกอบการ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 12
# 00:00:30,900 --> 00:00:32,500
# ของปี 2022
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 13
# 00:00:32,500 --> 00:00:33,466
# ของบริษัทนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 14
# 00:00:33,700 --> 00:00:35,466
# กับแนวโน้ม และทิศทางต่าง ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 15
# 00:00:35,500 --> 00:00:37,066
# ที่จะมาอัพเดทกันนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 16
# 00:00:37,533 --> 00:00:39,900
# ขออนุญาตไปที่ส่วนของ overview
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 17
# 00:00:39,900 --> 00:00:40,200
# ก่อน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 18
# 00:00:40,200 --> 00:00:42,766
# สําหรับคนที่อาจจะเพิ่งเคยรู้จักเรานะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 19
# 00:00:43,133 --> 00:00:44,300
# บริษัท โกลบอล คอนเน็คชั่นส์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 20
# 00:00:44,566 --> 00:00:49,700
# เป็นตัวแทนจําหน่ายผลิตภัณฑ์เกี่ยวกับปิโตรเคมีภัณฑ์ และพลาสติกนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 21
# 00:00:49,866 --> 00:00:50,666
# เม็ดพลาสติก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 22
# 00:00:51,000 --> 00:00:53,166
# ในธุรกิจอุตสาหกรรมปิโตรเคมี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 23
# 00:00:53,166 --> 00:00:55,100
# มีตั้งแต่ทางด้านต้นน้ำ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 24
# 00:00:55,100 --> 00:00:56,066
# ด้านซ้าย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 25
# 00:00:56,400 --> 00:00:58,000
# ไปถึงทางด้านปลายน้ำ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 26
# 00:00:58,000 --> 00:00:59,666
# ก็คือทางด้านผู้ผลิต polymer
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 27
# 00:00:59,666 --> 00:01:02,100
# หลัก ๆ กิจกรรมของเราก็คือการ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 28
# 00:01:02,666 --> 00:01:05,566
# ซื้อสินค้าจากผู้ผลิต polymer
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 29
# 00:01:05,966 --> 00:01:08,833
# ไปขายให้กับทางคอมพิวเตอร์ที่อยู่ทางด้านขวา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 30
# 00:01:09,400 --> 00:01:10,866
# กิจกรรมหลักจะเป็นอย่างนั้น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 31
# 00:01:11,000 --> 00:01:12,033
# แต่ขณะเดียวกัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 32
# 00:01:12,033 --> 00:01:15,100
# เรามีการขายสินค้าในหมวดที่เป็นพวก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 33
# 00:01:15,100 --> 00:01:15,600
# catalyst
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 34
# 00:01:15,600 --> 00:01:16,800
# หรือ chemical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 35
# 00:01:16,800 --> 00:01:18,433
# กลับขึ้นไปยังต้นน้ําด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 36
# 00:01:19,266 --> 00:01:21,833
# นี่ก็เป็นวัตถุดิบตั้งต้นสําหรับพวกผู้ผลิต
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 37
# 00:01:21,833 --> 00:01:23,166
# พวก Olefin Aromatic
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 38
# 00:01:23,733 --> 00:01:25,033
# หรือพวก Monomer ต่างๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 39
# 00:01:25,633 --> 00:01:26,633
# แต่อย่างที่เรียน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 40
# 00:01:26,833 --> 00:01:28,900
# กิจกรรมหลักอยู่ทางด้านขวามือ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 41
# 00:01:28,900 --> 00:01:32,666
# คือขายให้กับทางผู้แปรรูปสินค้าพลาสติก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 42
# 00:01:34,066 --> 00:01:36,800
# บริษัทเราก่อตั้งมาตั้งแต่ปี 94
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 43
# 00:01:36,933 --> 00:01:39,433
# ปีนี้ก็ย่างเข้าสู่ปีที่ 28
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 44
# 00:01:40,533 --> 00:01:41,333
# แล้วก็มี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 45
# 00:01:41,466 --> 00:01:42,166
# supplier
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 46
# 00:01:42,166 --> 00:01:44,831
# ที่สนับสนุนอยู่มากกว่า 30 บริษัท
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 47
# 00:01:45,066 --> 00:01:47,033
# สินค้าที่เกี่ยวข้องหลัก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 48
# 00:01:47,066 --> 00:01:48,966
# ก็แบ่งเป็น 3 กลุ่มหลัก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 49
# 00:01:48,966 --> 00:01:50,233
# ก็คือกลุ่มของ commodity
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 50
# 00:01:51,100 --> 00:01:52,766
# กลุ่มของ specialty engineering
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 51
# 00:01:52,766 --> 00:01:53,566
# แล้วก็ polymer
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 52
# 00:01:53,666 --> 00:01:55,133
# กับส่วนของยางด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 53
# 00:01:55,133 --> 00:01:55,933
# เป็น rubber
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 54
# 00:01:56,133 --> 00:01:58,266
# กับกลุ่มสุดท้าย ที่อาจจะเป็นกลุ่มเล็ก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 55
# 00:01:58,300 --> 00:01:59,333
# ก็คือกลุ่มของพวก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 56
# 00:01:59,566 --> 00:02:00,266
# additive
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 57
# 00:02:00,266 --> 00:02:01,566
# กับพวกสินค้าพวก intermediate
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 58
# 00:02:01,600 --> 00:02:03,266
# ที่ขายไปยังต้นน้ํานะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 59
# 00:02:05,333 --> 00:02:07,200
# บทบาทของบริษัท global connection
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 60
# 00:02:07,400 --> 00:02:10,466
# ในอุตสาหกรรมที่เราทําธุรกิจค้าขายอยู่ตอนนี้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 61
# 00:02:10,933 --> 00:02:12,700
# เราก็เป็นตัวกลาง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 62
# 00:02:12,700 --> 00:02:15,866
# เป็นสะพานที่เชื่อมโยงระหว่างผู้ผลิต
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 63
# 00:02:16,266 --> 00:02:17,933
# ที่เป็นชั้นนําของโลก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 64
# 00:02:17,933 --> 00:02:19,800
# ในแง่ของเทคโนโลยี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 65
# 00:02:19,933 --> 00:02:23,046
# ในแง่ของกําลังการผลิตในแต่ละสินค้าแต่ละชนิด
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 66
# 00:02:23,566 --> 00:02:29,000
# กับลูกค้าที่เป็นผู้แปรรูปในอุตสาหกรรมพลาสติกในบ้านเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 67
# 00:02:30,400 --> 00:02:32,866
# ด้วยความที่โครงสร้างอุตสาหกรรมบ้านเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 68
# 00:02:32,866 --> 00:02:34,866
# ต้องบอกว่าผู้แปรรูปมีจํานวนมาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 69
# 00:02:35,366 --> 00:02:38,233
# แต่ขณะเดียวกันส่วนใหญ่เป็นรายเล็กรายน้อย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 70
# 00:02:38,233 --> 00:02:38,800
# เป็น SME
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 71
# 00:02:38,800 --> 00:02:39,600
# มากกว่า 80%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 72
# 00:02:40,533 --> 00:02:41,933
# ทําให้บทบาทของเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 73
# 00:02:42,500 --> 00:02:46,100
# มีความสามารถที่จะรวบรวมเอาฐานข้อมูลจากลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 74
# 00:02:46,166 --> 00:02:48,166
# ฐานความต้องการจากลูกค้าทั้งหมดเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 75
# 00:02:48,433 --> 00:02:50,666
# มารวบรวมเป็นออเดอร์ก้อนโตได้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 76
# 00:02:50,666 --> 00:02:52,726
# แล้วก็สามารถที่จะสร้าง economy
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 77
# 00:02:53,400 --> 00:02:55,566
# of scale ให้กับทาง supplier
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 78
# 00:02:55,600 --> 00:02:59,466
# คือเรารวบรวมออเดอร์แล้วก็สั่งซื้อมาจํานวนมากได้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 79
# 00:02:59,933 --> 00:03:02,200
# ในขณะเดียวกันในส่วนของลูกค้าเอง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 80
# 00:03:02,666 --> 00:03:03,766
# มาหาเราครั้งเดียว
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 81
# 00:03:03,900 --> 00:03:04,766
# ก็สามารถได้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 82
# 00:03:04,766 --> 00:03:07,800
# economy of scope ไปก็คือ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 83
# 00:03:08,166 --> 00:03:08,800
# เหมือนคล้าย ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 84
# 00:03:08,800 --> 00:03:09,733
# one-stop shopping
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 85
# 00:03:09,733 --> 00:03:11,800
# ที่สามารถได้สินค้าที่หลากหลาย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 86
# 00:03:12,633 --> 00:03:17,733
# ซึ่งตรงนี้ เราสามารถให้บริการทั้งในส่วนของ logistics ด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 87
# 00:03:18,866 --> 00:03:20,033
# ตัวของ warehouseing
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 88
# 00:03:20,033 --> 00:03:21,333
# ที่เรามีการเก็บสินค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 89
# 00:03:21,733 --> 00:03:24,033
# แล้วก็สามารถส่งย่อยให้ได้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 90
# 00:03:24,400 --> 00:03:25,966
# แล้วก็มีการ repack
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 91
# 00:03:25,966 --> 00:03:26,733
# สินค้าให้ด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 92
# 00:03:26,733 --> 00:03:28,703
# ในขณะเดียวกันในเรื่องของ Sale & Marketing
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 93
# 00:03:29,166 --> 00:03:32,600
# การทํางานอย่างใกล้ชิดกัน ทั้งส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 94
# 00:03:32,600 --> 00:03:33,200
# supplier
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 95
# 00:03:33,200 --> 00:03:34,200
# กับส่วนของลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 96
# 00:03:34,533 --> 00:03:36,566
# ทําให้เราสามารถที่จะ work on
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 97
# 00:03:36,666 --> 00:03:37,700
# demand forecast
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 98
# 00:03:38,033 --> 00:03:41,766
# แล้วก็สามารถทําการวางแผนสินค้าคงคลังให้กับลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 99
# 00:03:42,266 --> 00:03:44,733
# ทําให้การผลิตต่าง ๆ smooth
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 100
# 00:03:44,833 --> 00:03:45,633
# นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 101
# 00:03:45,733 --> 00:03:48,433
# ในขณะเดียวกันการแก้ปัญหาในการผลิตหน้างาน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 102
# 00:03:48,766 --> 00:03:50,933
# เราก็ช่วยได้มากพอสมควร
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 103
# 00:03:50,933 --> 00:03:53,497
# ก็คือเนื่องจากเซลล์ ทีมเซลล์ของเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 104
# 00:03:53,497 --> 00:03:54,600
# มากกว่า 90%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 105
# 00:03:54,766 --> 00:03:55,700
# จบทางด้าน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 106
# 00:03:56,933 --> 00:03:57,633
# engineer
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 107
# 00:03:57,633 --> 00:03:58,766
# หรือว่า chemical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 108
# 00:03:58,766 --> 00:03:59,966
# หรือทางด้าน polymer
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 109
# 00:04:00,066 --> 00:04:00,966
# ทางด้าน science
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 110
# 00:04:01,133 --> 00:04:04,366
# เพราะฉะนั้นตรงนี้ ก็สามารถเหมือนกับเป็นตัวแทนของผู้ผลิต
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 111
# 00:04:04,433 --> 00:04:07,366
# ที่จะสามารถเข้าไปช่วยแก้ไขปัญหาเบื้องต้นได้เลย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 112
# 00:04:08,033 --> 00:04:09,366
# ในขณะเดียวกันทาง supplier
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 113
# 00:04:09,366 --> 00:04:10,400
# เราเองก็ยัง support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 114
# 00:04:10,433 --> 00:04:11,400
# ส่วนนี้ด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 115
# 00:04:11,833 --> 00:04:13,600
# ในขณะเดียวกันเรื่องของ financing
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 116
# 00:04:13,600 --> 00:04:14,366
# เรื่องของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 117
# 00:04:14,366 --> 00:04:14,933
# solution
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 118
# 00:04:14,933 --> 00:04:15,733
# ทางนี้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 119
# 00:04:15,733 --> 00:04:17,700
# ต้องบอกว่า เราเองก็จริงให้ไฟแนนซ์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 120
# 00:04:17,833 --> 00:04:19,500
# เหมือนให้ไฟแนนซ์ลูกค้าอยู่นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 121
# 00:04:19,500 --> 00:04:22,466
# เพราะว่าลูกค้าเนี่ย รับเงินจากเราไปเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 122
# 00:04:22,466 --> 00:04:25,400
# ก็สามารถที่จะได้เครดิตการค้าตรงนี้ด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 123
# 00:04:27,900 --> 00:04:33,479
# ในประวัติของเราเอง ตั้งแต่ก่อตั้งมาต้องบอกว่าเราเริ่มต้นธุรกิจในปี 94 จาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 124
# 00:04:34,300 --> 00:04:36,466
# กลุ่มอุตสาหกรรมพวกสินค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 125
# 00:04:36,733 --> 00:04:37,766
# community เป็นหลัก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 126
# 00:04:38,500 --> 00:04:40,233
# หลังจากนั้นเราค่อย ๆ เพิ่ม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 127
# 00:04:40,233 --> 00:04:42,466
# supplier ที่เข้ามา support เรามากขึ้นเรื่อย ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 128
# 00:04:43,666 --> 00:04:44,366
# แล้วก็ขยาย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 129
# 00:04:44,366 --> 00:04:49,500
# diversify กระจายตัวมาในสินค้ากลุ่มที่มีความเป็นเกรดพิเศษมากขึ้น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 130
# 00:04:50,200 --> 00:04:50,566
# ดูจาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 131
# 00:04:50,566 --> 00:04:51,933
# supplier ที่เข้ามา support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 132
# 00:04:51,966 --> 00:04:53,666
# ทั้งในส่วนของ Exxon
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 133
# 00:04:53,800 --> 00:04:56,366
# หรือว่าทางด้าน CHIMEI ที่เป็น ABS
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 134
# 00:04:57,100 --> 00:04:57,933
# ก็เพิ่มเข้ามา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 135
# 00:04:58,366 --> 00:05:02,800
# แล้วเราก็พยายามที่จะเติบโตให้ได้อย่างมั่นคง และยั่งยืน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 136
# 00:05:02,933 --> 00:05:06,300
# โดยที่เราเข้าจดทะเบียนในตลาดหลักทรัพย์ ตั้งแต่ปี 2005
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 137
# 00:05:06,533 --> 00:05:07,666
# มาจนถึงปัจจุบัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 138
# 00:05:08,433 --> 00:05:10,833
# ปีที่แล้วระหว่างทาง เราก็ได้มี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 139
# 00:05:11,166 --> 00:05:12,800
# distributorship เพิ่มขึ้นเรื่อย ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 140
# 00:05:13,433 --> 00:05:15,800
# คือจดทะเบียนจริง ๆ ต้องบอกว่า ตอนเข้าตลาดก็คือ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 141
# 00:05:15,800 --> 00:05:16,166
# 200 ล้าน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 142
# 00:05:16,166 --> 00:05:19,666
# นับจากวันนั้น มีเพิ่มทุนครั้งเดียว คือปีที่แล้วก็คือ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 143
# 00:05:20,366 --> 00:05:21,166
# ปี 2022
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 144
# 00:05:21,333 --> 00:05:24,446
# แต่เป็นการเพิ่มทุนลักษณะที่เป็นการจ่ายหุ้นปันผล
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 145
# 00:05:24,446 --> 00:05:27,033
# จาก 200 ล้าน มาเป็น 220 ล้าน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 146
# 00:05:27,666 --> 00:05:29,766
# ก็คือนําหุ้นปันผลตัวนี้ add up เข้ามา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 147
# 00:05:32,333 --> 00:05:33,433
# สินค้าของเรานะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 148
# 00:05:33,433 --> 00:05:36,266
# ก็คือจะมีอย่างที่เรียนไปตอนต้นค่ะ ว่าเป็น commodity
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 149
# 00:05:36,933 --> 00:05:37,733
# กับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 150
# 00:05:37,733 --> 00:05:39,466
# specialty แล้วก็ตัว chemical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 151
# 00:05:39,666 --> 00:05:41,066
# นะคะ ตัวของ commodity
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 152
# 00:05:41,766 --> 00:05:43,833
# producer ที่ support เราหลัก ๆ เลยก็คือ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 153
# 00:05:44,456 --> 00:05:45,923
# กลุ่มผู้ผลิตในประเทศ ทางกลุ่ม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 154
# 00:05:46,166 --> 00:05:48,300
# GC ก็คือ PTTGC
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 155
# 00:05:48,633 --> 00:05:49,466
# เป็นผู้ผลิตหลัก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 156
# 00:05:49,766 --> 00:05:52,166
# ก็จะมีทั้งทางด้าน HMC,  IRPC
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 157
# 00:05:52,366 --> 00:05:52,700
# นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 158
# 00:05:52,700 --> 00:05:55,833
# นอกจากนั้นก็ยังมีผู้ผลิตเกรดพิเศษที่เป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 159
# 00:05:55,833 --> 00:05:56,266
# community
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 160
# 00:05:56,266 --> 00:05:57,200
# เกรดพิเศษเข้ามา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 161
# 00:05:57,200 --> 00:05:58,466
# support เราอีกด้วยส่วนหนึ่ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 162
# 00:05:58,866 --> 00:06:00,800
# ในขณะที่ในกลุ่มของ business unit
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 163
# 00:06:00,800 --> 00:06:02,533
# ที่เป็น speciality engineering
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 164
# 00:06:03,433 --> 00:06:05,166
# ส่วนใหญ่แล้วจะเป็นการ import
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 165
# 00:06:05,166 --> 00:06:05,966
# จากต่างประเทศ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 166
# 00:06:06,466 --> 00:06:08,166
# โดยที่มีผู้ผลิต support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 167
# 00:06:08,166 --> 00:06:08,966
# อย่างเช่น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 168
# 00:06:09,266 --> 00:06:10,133
# ตัวของ Exxon
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 169
# 00:06:11,433 --> 00:06:12,233
# CHIMEI
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 170
# 00:06:12,666 --> 00:06:13,466
# CABOT
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 171
# 00:06:14,400 --> 00:06:15,033
# Celanese
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 172
# 00:06:15,033 --> 00:06:17,400
# ซึ่งอันนี้ช่วงหลังก็จะมีการขยับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 173
# 00:06:17,900 --> 00:06:19,166
# บทบาทมากขึ้นนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 174
# 00:06:19,333 --> 00:06:21,166
# DUPONT หรือ TRINSEO นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 175
# 00:06:21,300 --> 00:06:25,133
# รวมถึงมีการผลิตสินค้าที่อยู่ในเกรดที่เป็นส่วนที่เรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 176
# 00:06:25,466 --> 00:06:27,533
# ทําสูตรขึ้นมาเองภายใต้แบรนด์ GIC
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 177
# 00:06:27,600 --> 00:06:28,400
# ด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 178
# 00:06:28,800 --> 00:06:30,266
# นอกจากนั้น พอใน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 179
# 00:06:30,333 --> 00:06:32,066
# ในส่วนของ specialty chemical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 180
# 00:06:32,133 --> 00:06:32,766
# อันเนี้ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 181
# 00:06:32,766 --> 00:06:33,300
# หลัก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 182
# 00:06:33,300 --> 00:06:35,066
# จะเป็นพวก plastic additives ค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 183
# 00:06:35,500 --> 00:06:36,700
# ผู้ที่เข้ามา support เราหลัก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 184
# 00:06:36,766 --> 00:06:38,733
# ตอนนี้ก็จะเป็นทางด้าน BASF นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 185
# 00:06:39,333 --> 00:06:40,233
# ในส่วนของ chemical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 186
# 00:06:40,266 --> 00:06:41,400
# ที่ขายอยู่ในต้นน้ํา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 187
# 00:06:41,866 --> 00:06:42,466
# ผู้ support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 188
# 00:06:42,466 --> 00:06:43,933
# หลักก็จะเป็นตัว Chevron Phillips
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 189
# 00:06:44,666 --> 00:06:45,433
# นอกจากนั้น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 190
# 00:06:45,433 --> 00:06:47,366
# เราก็ยังมีบริการในเรื่องของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 191
# 00:06:47,366 --> 00:06:48,408
# water & resolution
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 192
# 00:06:48,400 --> 00:06:50,500
# ซึ่งอันนี้จะเป็นผู้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 193
# 00:06:50,533 --> 00:06:51,166
# support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 194
# 00:06:51,166 --> 00:06:52,566
# ในเรื่องผลิตภัณฑ์เป็นคนไทย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 195
# 00:06:52,966 --> 00:06:54,433
# บริษัท Genugreen
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 196
# 00:06:54,633 --> 00:06:55,500
# ภายใต้แบรนด์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 197
# 00:06:55,633 --> 00:06:56,433
# Micronized
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 198
# 00:06:57,400 --> 00:06:58,400
# ก็จะมีส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 199
# 00:06:58,500 --> 00:06:59,166
# additives
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 200
# 00:06:59,166 --> 00:07:00,000
# ก็ยังมีอย่างอื่น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 201
# 00:07:00,000 --> 00:07:02,066
# อย่างพวกตัวของ Milliken
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 202
# 00:07:02,566 --> 00:07:04,166
# ก็เป็นตัวที่เข้ามา support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 203
# 00:07:04,166 --> 00:07:04,966
# เราด้วยเหมือนกัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 204
# 00:07:05,100 --> 00:07:07,800
# อันนี้ก็จะเป็นภาพรวมของผลิตภัณฑ์นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 205
# 00:07:07,800 --> 00:07:10,600
# แล้วก็ผู้ผลิตที่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 206
# 00:07:10,666 --> 00:07:11,300
# support
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 207
# 00:07:11,300 --> 00:07:12,700
# สินค้าให้กับเรานะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 208
# 00:07:14,966 --> 00:07:16,066
# อุตสาหกรรมที่เราโฟกัส
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 209
# 00:07:16,466 --> 00:07:17,866
# จริง ๆ หลัก ๆ ก็จะอยู่ใน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 210
# 00:07:18,233 --> 00:07:19,966
# 3 กลุ่มอุตสาหกรรมหลักตรงนี้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 211
# 00:07:20,566 --> 00:07:22,633
# จะแบ่งแยกเป็น 7 อุตสาหกรรมย่อย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 212
# 00:07:22,900 --> 00:07:24,566
# อย่างเช่น ตัว automotive
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 213
# 00:07:25,133 --> 00:07:25,700
# อันนี้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 214
# 00:07:25,700 --> 00:07:27,233
#  cover ทั้งในส่วนของภายใน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 215
# 00:07:27,233 --> 00:07:27,800
# ภายนอก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 216
# 00:07:27,800 --> 00:07:29,833
# แล้วก็ในเครื่องยนต์ด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 217
# 00:07:29,833 --> 00:07:31,500
# แล้วก็ส่วนของ industrial
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 218
# 00:07:31,700 --> 00:07:32,833
# ก็จะมีทั้งส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 219
# 00:07:32,833 --> 00:07:34,166
# electrical and appliance
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 220
# 00:07:35,033 --> 00:07:35,766
# construction
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 221
# 00:07:35,766 --> 00:07:36,866
# ในเรื่องของการก่อสร้าง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 222
# 00:07:36,933 --> 00:07:37,700
# เรื่องของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 223
# 00:07:37,700 --> 00:07:38,900
# adhesive and sylence
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 224
# 00:07:38,966 --> 00:07:40,233
# จะเป็นเรื่องของกาว
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 225
# 00:07:40,500 --> 00:07:41,300
# ยาง ต่างๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 226
# 00:07:41,766 --> 00:07:43,033
# ในขณะที่ consumer product
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 227
# 00:07:43,166 --> 00:07:45,366
# จะเป็นกลุ่มใหญ่อีกกลุ่มหนึ่ง ก็คือกลุ่มของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 228
# 00:07:45,366 --> 00:07:46,166
# packaging
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 229
# 00:07:46,300 --> 00:07:48,200
# แยกไปทั้งตัวของ flexible film
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 230
# 00:07:48,233 --> 00:07:49,033
# หรือ rigid
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 231
# 00:07:49,500 --> 00:07:52,166
# ขณะเดียวกันเรื่องของอุตสาหกรรมพวกรองเท้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 232
# 00:07:52,166 --> 00:07:53,000
# medical ต่างๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 233
# 00:07:53,166 --> 00:07:55,666
# เราก็พยายามเข้าไปมีบทบาทตรงนั้นด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 234
# 00:07:57,466 --> 00:07:58,733
# ยอดขายของบริษัท
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 235
# 00:07:58,733 --> 00:08:01,266
# ปริมาณขายของบริษัทในปีที่ผ่านมา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 236
# 00:08:01,266 --> 00:08:02,300
# เปรียบเทียบกันค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 237
# 00:08:02,333 --> 00:08:03,133
# เงินปัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 238
# 00:08:03,166 --> 00:08:04,500
# ใกล้เคียงกับปีก่อน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 239
# 00:08:04,933 --> 00:08:06,762
# ดรอปไปนิด ประมาณ 1%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 240
# 00:08:06,900 --> 00:08:09,833
# จากประมาณ 93,300 ตัน เหลือประมาณ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 241
# 00:08:10,066 --> 00:08:11,800
# 92,200 ตัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 242
# 00:08:14,100 --> 00:08:14,733
# ความหลัก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 243
# 00:08:14,733 --> 00:08:16,733
# ความกระจายตัวยังใกล้เคียงเดิม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 244
# 00:08:16,733 --> 00:08:18,833
# ก็คือยังอยู่กับทาง packaging
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 245
# 00:08:19,133 --> 00:08:19,933
# เกือบ 50%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 246
# 00:08:20,933 --> 00:08:22,233
# แล้วก็ลําดับถัดมาเป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 247
# 00:08:22,233 --> 00:08:23,033
# consumer product
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 248
# 00:08:23,466 --> 00:08:24,300
# เป็น automative
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 249
# 00:08:24,400 --> 00:08:26,066
# แล้วก็ทางปิโตรเคมี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 250
# 00:08:26,366 --> 00:08:27,333
# ลําดับ หนึ่ง สอง สาม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 251
# 00:08:27,333 --> 00:08:28,833
# นี่รวมกันก็ประมาณเกือบ 80%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 252
# 00:08:29,100 --> 00:08:30,100
# ของ port แล้วนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 253
# 00:08:30,366 --> 00:08:33,500
# ซึ่งจริง ๆ ก็จะใกล้เคียง กับภาพรวมของอุตสาหกรรมนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 254
# 00:08:34,833 --> 00:08:39,900
# ถัดไปอันนี้คือ อย่างที่พี่เรียนในภาพใหญ่เมื่อสักครู่ค่ะ โดยรวมใกล้เคียงกับเดิม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 255
# 00:08:40,033 --> 00:08:42,700
# แต่ทั้งโครงสร้างข้างใน จริงๆ แล้วเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 256
# 00:08:42,900 --> 00:08:45,133
# มีในส่วนของตัว
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 257
# 00:08:45,766 --> 00:08:47,300
# ความเปลี่ยนแปลงเพิ่มขึ้นลดลง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 258
# 00:08:47,633 --> 00:08:49,466
# จะเห็นว่าทาง packaging
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 259
# 00:08:49,833 --> 00:08:51,100
# ยังมีการเติบโตอยู่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 260
# 00:08:51,800 --> 00:08:53,966
# ก็คือมีการเติบโตได้ 8%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 261
# 00:08:54,066 --> 00:08:55,666
# กับตัวทางด้าน petrochemicals
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 262
# 00:08:56,000 --> 00:08:58,766
# แต่ว่ามันมีส่วนที่ลดลงบ้าง ก็คือในส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 263
# 00:08:59,966 --> 00:09:01,566
# ตัวของ consumer product automative
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 264
# 00:09:01,733 --> 00:09:02,766
# แล้วก็ electrical
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 265
# 00:09:02,866 --> 00:09:04,766
# ซึ่งลดลงค่อนข้างมากในปีที่แล้ว
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 266
# 00:09:05,366 --> 00:09:09,533
# แต่อันนี้ก็สะท้อนไปกับตัวภาพของความ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 267
# 00:09:10,566 --> 00:09:19,200
# ความต้องการใช้กับแนวโน้มเศรษฐกิจที่อาจจะกังวลกับการถดถอยนะคะ กับภาพรวมของเศรษฐกิจในบ้านเราด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 268
# 00:09:20,333 --> 00:09:25,066
# ทีนี้ก็ไปถึงในส่วนของตัวกลยุทธ์ที่เราดําเนินงานอยู่นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 269
# 00:09:25,333 --> 00:09:29,966
# ส่วนแรกคือ เรื่องของการพยายามสร้างความยืดหยุ่น แล้วก็ความสามารถในการแข่งขัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 270
# 00:09:30,366 --> 00:09:32,300
# ความยืดหยุ่น ในที่นี้คือ ต้องบอกว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 271
# 00:09:32,433 --> 00:09:36,100
# portfolio ของเรามีการกระจายตัว ทั้งในแง่ของลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 272
# 00:09:36,433 --> 00:09:37,566
# ทั้งในแง่ของอุตสาหกรรม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 273
# 00:09:38,666 --> 00:09:39,900
# คือลูกค้าเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 274
# 00:09:40,700 --> 00:09:43,333
# จะบอกว่าแต่ละรายใน port ของเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 275
# 00:09:44,066 --> 00:09:48,266
# จะมีการขายสินค้ามูลค่าขายทั้ง port
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 276
# 00:09:48,366 --> 00:09:50,433
# ไม่มีรายใดที่มีมูลค่าเกิน 5%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 277
# 00:09:50,466 --> 00:09:51,300
# ของ port เลย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 278
# 00:09:51,533 --> 00:09:53,933
# เพราะฉะนั้นต้องบอกว่ามีการกระจายตัวค่อนข้างมาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 279
# 00:09:54,000 --> 00:09:57,133
# ในขณะเดียวกัน การสร้างความแข็งแกร่งในเรื่องของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 280
# 00:09:57,833 --> 00:09:59,833
# guideline development อันนี้เป็น key
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 281
# 00:10:00,300 --> 00:10:02,033
# สําคัญที่ทําให้เรายังเติบโตอยู่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 282
# 00:10:02,166 --> 00:10:04,666
# เพราะว่าเรามีการร่วม co-create
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 283
# 00:10:04,766 --> 00:10:08,133
# กับส่วนทั้ง supplier ทั้งลูกค้าในการที่จะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 284
# 00:10:08,700 --> 00:10:10,800
# การนํานวัตกรรมใหม่ ๆ เข้ามา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 285
# 00:10:10,966 --> 00:10:14,500
# ทําให้เกิดการขายในส่วนที่ต่อยอดไปได้มากขึ้นนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 286
# 00:10:14,833 --> 00:10:17,900
# ขณะเดียวกันเรื่องของ process improvement ก็เป็นส่วนที่เราให้ความสําคัญ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 287
# 00:10:18,166 --> 00:10:20,766
# มีการใช้โครงการ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 288
# 00:10:20,900 --> 00:10:22,566
# best suggestion awards ในบริษัท
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 289
# 00:10:22,566 --> 00:10:26,566
# เพื่อที่ให้เกิดคําแนะนํามาปรับปรุงกระบวนการทํางานนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 290
# 00:10:27,200 --> 00:10:28,000
# ส่วนเรื่องของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 291
# 00:10:28,233 --> 00:10:37,033
# risk management เรื่องของการบริหารความเสี่ยง ซึ่งเป็นข้อสําคัญมากนะคะ ก็คือในส่วนทั้งเรื่องของการบริหารหนี้สงสัยจะเป็นศูนย์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 292
# 00:10:37,066 --> 00:10:39,766
# การบริหารสินค้าคงคลัง การบริหารอัตราแลกเปลี่ยนต่างๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 293
# 00:10:40,300 --> 00:10:46,666
# เพราะว่าค่าใช้จ่ายต่าง ๆ เหล่านี้ ถ้าเกิดอุบัติเหตุขึ้นมา ก็กระทบกับผลประกอบการพอสมควรนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 294
# 00:10:47,266 --> 00:10:51,266
# ในขณะเดียวกัน ก็พยายามที่จะใช้ตัวฐานข้อมูลให้เป็นประโยชน์มากที่สุด
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 295
# 00:10:52,866 --> 00:10:54,200
# นอกจากนี้ ในส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 296
# 00:10:55,133 --> 00:10:55,733
# staff
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 297
# 00:10:55,733 --> 00:10:59,133
# เรื่องของบุคลากร ก็มีความสําคัญค่อนข้างมาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 298
# 00:10:59,866 --> 00:11:01,833
# เรามีโครงการที่จะทํา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 299
# 00:11:02,266 --> 00:11:04,933
# IDP Project สําหรับพนักงานที่เป็นกลุ่ม talent
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 300
# 00:11:04,933 --> 00:11:05,733
# อยู่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 301
# 00:11:06,066 --> 00:11:08,633
# นอกจากนี้ในส่วนของ supply chain ต้องบอกว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 302
# 00:11:09,166 --> 00:11:12,333
# ก็มามองทั้งกลุ่มเลย ไม่ใช่แค่เรากับลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 303
# 00:11:12,700 --> 00:11:13,766
# หรือเรากับ supplier
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 304
# 00:11:13,866 --> 00:11:15,600
# ก็ดูทั้งห่วงโซ่นี้อยากให้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 305
# 00:11:16,200 --> 00:11:18,666
# เราสรรหาผลิตภัณฑ์ที่มีความยั่งยืน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 306
# 00:11:18,900 --> 00:11:22,033
# ผู้ผลิตที่เป็นผู้นําผลิตภัณฑ์อุตสาหกรรม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 307
# 00:11:22,033 --> 00:11:23,433
# ส่งต่อให้กับลูกค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 308
# 00:11:23,433 --> 00:11:26,433
# ที่สามารถนําไปใช้งานได้อย่างมีคุณภาพ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 309
# 00:11:26,633 --> 00:11:29,733
# ผ่านพนักงานขายที่มีคุณภาพด้วยเช่นกัน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 310
# 00:11:29,900 --> 00:11:31,366
# เราก็จะเติบโตไปด้วยกันทั้ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 311
# 00:11:31,366 --> 00:11:32,266
# supply chain ได้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 312
# 00:11:32,466 --> 00:11:34,133
# ในขณะเดียวกันต้องบอกว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 313
# 00:11:34,266 --> 00:11:36,233
# ปัจจุบันเราก็พยายามส่งเสริม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 314
# 00:11:36,533 --> 00:11:39,066
# สรรหาเกี่ยวกับนวัตกรรมสินค้า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 315
# 00:11:39,066 --> 00:11:41,333
# ผลิตภัณฑ์ที่มีเพื่อสิ่งแวดล้อมมากขึ้น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 316
# 00:11:41,966 --> 00:11:44,400
# รวมถึงให้ความรู้เกี่ยวกับผลิตภัณฑ์พลาสติก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 317
# 00:11:44,966 --> 00:11:47,400
# ทั้งทีมงาน ทั้งคู่ค้าของเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 318
# 00:11:47,400 --> 00:11:48,466
# รวมถึงสังคมด้วย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 319
# 00:11:48,466 --> 00:11:49,500
# เพื่อให้เพิ่มความเข้าใจว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 320
# 00:11:49,866 --> 00:11:54,566
# เราจะสร้างการมีส่วนร่วมในการอุปโภคสินค้าพลาสติกอย่างยั่งยืนได้อย่างไรบ้าง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 321
# 00:11:54,700 --> 00:12:02,300
# และสุดท้ายคือ ในส่วนของการทําในส่วนของการทําธุรกิจอย่างมีจริยธรรม และโปร่งใสนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 322
# 00:12:04,600 --> 00:12:05,533
# ถัดไปนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 323
# 00:12:05,633 --> 00:12:06,433
# คือปกติ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 324
# 00:12:06,633 --> 00:12:09,366
# ก็จะขออนุญาตเอาข้อมูลของอุตสาหกรรมมาอัปเดต
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 325
# 00:12:09,366 --> 00:12:10,566
# อย่างน้อยสักปีละครั้ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 326
# 00:12:10,600 --> 00:12:14,600
# มันจะมีข้อมูลตัวเลขจากสถาบันพลาสติกเข้ามา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 327
# 00:12:15,133 --> 00:12:17,633
# เพื่อที่จะเห็นภาพการเปลี่ยนแปลง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 328
# 00:12:17,633 --> 00:12:18,633
# แล้วก็ประเมินสถานการณ์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 329
# 00:12:19,666 --> 00:12:22,366
# แต่ว่าข้อมูลต้องบอกว่าก็อาจจะไม่ได้อัปเดตมาก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 330
# 00:12:22,366 --> 00:12:23,100
# สิ่งที่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 331
# 00:12:23,100 --> 00:12:24,400
# publish ในปี 25
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 332
# 00:12:24,466 --> 00:12:25,400
# ช่วงปลาย ๆ ปี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 333
# 00:12:25,700 --> 00:12:27,466
# เป็นข้อมูลของฐานที่เขา survey
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 334
# 00:12:27,466 --> 00:12:28,933
# อยู่ในช่วงปี 64 นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 335
# 00:12:29,200 --> 00:12:31,166
# ก็คือ 2022 ประกาศของ 2021
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 336
# 00:12:31,433 --> 00:12:32,433
# นั่นเองนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 337
# 00:12:34,100 --> 00:12:36,366
# จํานวนผู้ประกอบการในพลาสติก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 338
# 00:12:36,500 --> 00:12:37,666
# ต้องบอกว่าประมาณ 65%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 339
# 00:12:38,633 --> 00:12:40,833
# เป็นกลุ่มของผู้แปรรูป
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 340
# 00:12:40,933 --> 00:12:42,500
# ก็คือกลุ่มลูกค้าของเราประมาณ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 341
# 00:12:42,500 --> 00:12:43,733
# 2,200 กว่าราย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 342
# 00:12:44,466 --> 00:12:48,133
# นอกนั้นก็จะมีกระจายตัวไป ในเรื่องของพวกรีไซเคิลบ้าง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 343
# 00:12:48,133 --> 00:12:49,366
# ประกอบชิ้นส่วนบ้าง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 344
# 00:12:49,366 --> 00:12:50,266
# ตัวแทนจัดจําหน่ายบ้าง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 345
# 00:12:50,266 --> 00:12:51,266
# ซึ่งเป็นส่วนน้อยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 346
# 00:12:51,533 --> 00:12:53,166
# อย่างที่เรียนไปเมื่อสักครู่ค่ะว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 347
# 00:12:53,166 --> 00:12:55,866
# ขนาดกิจการของผู้ประกอบการพลาสติกในบ้านเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 348
# 00:12:56,100 --> 00:12:58,706
# หลัก ๆ เป็น SME ประมาณ 88.5%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 349
# 00:12:59,566 --> 00:13:00,566
# จริง ๆ แล้ว SME
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 350
# 00:13:00,666 --> 00:13:02,186
# เป็น small สัก 60%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 351
# 00:13:02,266 --> 00:13:03,066
# ด้วยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 352
# 00:13:03,100 --> 00:13:04,500
# ทําให้มันเป็น gap
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 353
# 00:13:04,733 --> 00:13:05,966
# ที่ทําให้ distributor
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 354
# 00:13:06,133 --> 00:13:07,133
# ยังสามารถเข้าไป
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 355
# 00:13:07,566 --> 00:13:09,966
# ช่วยให้บริการสร้างคุณค่าให้กับตรงนั้นได้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 356
# 00:13:09,966 --> 00:13:12,133
# เพราะว่าการที่ผู้ผลิตรายใหญ่ ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 357
# 00:13:12,166 --> 00:13:13,533
# เขาจะมาส่งย่อยเล็ก ๆ น้อย ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 358
# 00:13:13,566 --> 00:13:15,666
# กับพวกแปรรูปรายเล็ก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 359
# 00:13:16,466 --> 00:13:19,000
# มันก็ไม่คุ้มทุนทั้งสองส่วนเลย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 360
# 00:13:20,933 --> 00:13:24,300
# และในส่วนของภาคอุตสาหกรรมพลาสติก
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 361
# 00:13:24,333 --> 00:13:27,600
# ต้องบอกว่าประเทศไทยเป็นประเทศ next export
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 362
# 00:13:27,600 --> 00:13:29,633
# ในส่วนของกลุ่มพลาสติกเรซิ่นนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 363
# 00:13:30,533 --> 00:13:32,233
# เรามี producer ในบ้านเรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 364
# 00:13:32,433 --> 00:13:33,233
# 2 กลุ่มใหญ่ ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 365
# 00:13:33,300 --> 00:13:35,233
# จากกลุ่ม SCG คือกลุ่ม PTTGC
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 366
# 00:13:36,200 --> 00:13:38,663
# ผลิตได้อยู่ราว ๆ รวมกันประมาณปีละ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 367
# 00:13:38,666 --> 00:13:40,200
# 9.5 ล้านตัน นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 368
# ...
# Moviepy - Command successful
# 768
# 00:26:12,633 --> 00:26:13,433
# จะเป็นเรื่อง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 769
# 00:26:14,600 --> 00:26:15,900
# ต้องการเงินสดไหม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 770
# 00:26:15,900 --> 00:26:17,200
# อันนี้ไม่มีนะครับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 771
# 00:26:17,266 --> 00:26:19,400
# กระแสเงินสดของเราแข็งแรงนะครับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 772
# 00:26:19,633 --> 00:26:21,566
# ก็ไม่ได้มีปัญหาใด ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 773
# 00:26:21,566 --> 00:26:23,666
# อันนี้ไม่ได้เป็นเหตุผลในการที่เรา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 774
# 00:26:25,200 --> 00:26:29,166
# จ่ายเงินปันผลเป็นลูกของหุ้นนะครับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 775
# 00:26:31,733 --> 00:26:32,533
# ขอบคุณค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 776
# 00:26:33,500 --> 00:26:35,500
# มีคําถามกลับมาเรื่องธุรกิจนิดนึงนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 777
# 00:26:36,266 --> 00:26:38,366
# มีคําถามลงไปลึกเลยว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 778
# 00:26:38,666 --> 00:26:39,600
# งานที่เรารับแบบ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 779
# 00:26:39,866 --> 00:26:40,666
# conventional
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 780
# 00:26:40,666 --> 00:26:41,600
# กับ non conventional เนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 781
# 00:26:41,966 --> 00:26:43,400
# เป็นลักษณะของการรับแบบ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 782
# 00:26:43,433 --> 00:26:44,000
# porter share
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 783
# 00:26:44,000 --> 00:26:44,966
# หรือ express of loss
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 784
# 00:26:44,966 --> 00:26:45,766
# นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 785
# 00:26:45,833 --> 00:26:47,033
# อันนี้จะเป็น technical term
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 786
# 00:26:47,033 --> 00:26:48,200
# นิดนึง ก็เป็นแบบ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 787
# 00:26:48,366 --> 00:26:49,300
# รับประกันแบบหนึ่ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 788
# 00:26:49,300 --> 00:26:50,933
# แต่ว่างานทั้งหมดที่เรารับเข้ามาเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 789
# 00:26:50,933 --> 00:26:51,733
# เรารับเป็นแบบ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 790
# 00:26:52,100 --> 00:26:53,666
# เราไม่ได้รับแบบ excel of loss นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 791
# 00:26:53,933 --> 00:26:54,733
# เราจะรับเป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 792
# 00:26:55,233 --> 00:26:56,033
# เรียกว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 793
# 00:26:56,133 --> 00:26:57,800
# porter share หรือบางทีมันจะเป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 794
# 00:26:58,033 --> 00:27:00,466
# ลักษณะของการเป็น retention
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 795
# 00:27:00,466 --> 00:27:01,839
# เป็นลําดับขั้นนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 796
# 00:27:01,839 --> 00:27:03,331
# แต่เราไม่ได้รับ xl นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 797
# 00:27:05,400 --> 00:27:06,333
# มีคําถามว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 798
# 00:27:07,766 --> 00:27:08,500
# คือเข้าใจว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 799
# 00:27:08,500 --> 00:27:10,433
# นักลงทุนถามว่า บริษัทลูกค้าเราเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 800
# 00:27:10,433 --> 00:27:12,000
# ก็คือบริษัทประกันต้นทางเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 801
# 00:27:12,166 --> 00:27:13,333
# เขามีขนาดที่ใหญ่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 802
# 00:27:13,366 --> 00:27:14,733
# แล้วมีทุนที่ใหญ่กว่ามาก ๆ เนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 803
# 00:27:16,633 --> 00:27:17,433
# เหมือนกับมีความ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 804
# 00:27:17,500 --> 00:27:20,000
# ทําไมเขาถึงจําเป็นจะต้องบริหารความเสี่ยง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 805
# 00:27:20,000 --> 00:27:21,333
# โดยการส่งต่อมาที่บริษัท
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 806
# 00:27:21,333 --> 00:27:22,333
# reinsurer นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 807
# 00:27:24,033 --> 00:27:24,833
# ซึ่ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 808
# 00:27:26,533 --> 00:27:27,766
# ต้องอธิบายอย่างนี้ว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 809
# 00:27:27,766 --> 00:27:28,633
# บริษัทประกันชีวิต
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 810
# 00:27:28,666 --> 00:27:31,233
# ปกติแล้วเขาต้องบริหารความเสี่ยงอยู่แล้วนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 811
# 00:27:31,233 --> 00:27:32,766
# เขาก็จะไม่เก็บไว้ทั้งหมดนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 812
# 00:27:32,766 --> 00:27:34,400
# แล้วก็การบริหารความเสี่ยงของเขาเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 813
# 00:27:34,633 --> 00:27:36,233
# เขาก็จะดูหลายปัจจัยนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 814
# 00:27:36,733 --> 00:27:38,106
# เช่นว่า อ่า โอเค
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 815
# 00:27:38,106 --> 00:27:39,681
# เป็นบริษัท partner กันนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 816
# 00:27:39,681 --> 00:27:40,933
# หรือว่าการที่เขาส่งต่อเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 817
# 00:27:40,933 --> 00:27:42,166
# เขาต้องส่งหาหลาย ๆ คน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 818
# 00:27:42,166 --> 00:27:43,066
# เพื่อกระจายความเสี่ยง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 819
# 00:27:43,066 --> 00:27:44,766
# เขาจะไม่ส่งหาบริษัทใดบริษัทหนึ่ง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 820
# 00:27:44,766 --> 00:27:46,005
# บริษัทเดียวนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 821
# 00:27:46,005 --> 00:27:46,533
# เพราะฉะนั้นเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 822
# 00:27:46,600 --> 00:27:48,366
# เขาก็ต้องมีการกระจายว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 823
# 00:27:48,600 --> 00:27:49,633
# 1 สัญญาของเขา
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 824
# 00:27:49,633 --> 00:27:52,130
# เขาจะมี panel รับกี่คนนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 825
# 00:27:52,166 --> 00:27:53,766
# โดยที่เค้าจะเลือกเราหรือเปล่านะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 826
# 00:27:53,766 --> 00:27:58,133
# เค้าก็จะมาดูว่างบการเงินเราเนี่ยแม้ว่าเราเล็กกว่าเค้า
# แต่เรามั่นคงใน scale ของเราหรือเปล่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 827
# 00:27:58,233 --> 00:28:04,300
# เพราะฉะนั้นเนี่ยบริษัทไทยรีประกันชีวิตเราเองในการที่
# เรารักษาระดับ car ratio หรือ capital เราได้เนี่ยเกินกว่า 300% เนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 828
# 00:28:04,366 --> 00:28:09,333
# มันเทียบเท่ากับ triple-A rating นะคะเวลาที่เราทํางาน
# เพราะฉะนั้นเนี่ยความมั่นคงทาง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 829
# 00:28:09,666 --> 00:28:10,333
# balance sheet
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 830
# 00:28:10,333 --> 00:28:10,700
# แล้วก็
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 831
# 00:28:10,700 --> 00:28:11,633
# capital ของเราเนี่ยมั่นคง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 832
# 00:28:12,166 --> 00:28:12,966
# แล้วก็การ service
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 833
# 00:28:13,066 --> 00:28:15,000
# ที่สามารถจะตอบโจทย์ลูกค้าได้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 834
# 00:28:15,000 --> 00:28:16,633
# ตัวนี้ก็เป็นจุดเด่น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 835
# 00:28:16,633 --> 00:28:17,400
# ที่ยังไงก็ตาม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 836
# 00:28:17,400 --> 00:28:19,500
# ถึงแม้ว่าบริษัทประกันหน้าบ้านเค้าใหญ่แค่ไหน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 837
# 00:28:19,500 --> 00:28:20,633
# ในเวลาที่เค้าต้องบริหารความเสี่ยง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 838
# 00:28:20,800 --> 00:28:24,500
# เค้าก็จะเลือกเราเป็นหนึ่งในลูกค้าของเค้าเสมอนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 839
# 00:28:26,376 --> 00:28:31,866
# ที่นี้ อันนี้ก็จบไปในมุมของการเลือกตัว
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 840
# 00:28:34,066 --> 00:28:35,033
# การส่งประกันต่อนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 841
# 00:28:35,800 --> 00:28:38,266
# กลับมาในส่วนของอัตราดอกเบี้ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 842
# 00:28:38,266 --> 00:28:40,533
# และ port จัดลงทุนเรานิดนึงot8t
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 843
# 00:28:40,600 --> 00:28:43,300
# port ลงทุนจะเห็นว่าเรามีส่วนของ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 844
# 00:28:43,300 --> 00:28:43,833
# reit
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 845
# 00:28:43,833 --> 00:28:46,966
# แต่ทีนี้ก็จะมีนักลงทุนให้ข้อสังเกตมองว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 846
# 00:28:47,600 --> 00:28:49,100
# การที่อัตราดอกเบี้ยมันเป็นขาขึ้น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 847
# 00:28:49,200 --> 00:28:51,566
# แล้วเรายังมีเงินลงทุนผ่านกองทุนที่เป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 848
# 00:28:51,566 --> 00:28:51,933
# prop fund
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 849
# 00:28:51,933 --> 00:28:52,466
# กับ reit fund
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 850
# 00:28:52,466 --> 00:28:53,700
# นะคะ ถ้าโดยสัดส่วนแล้วเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 851
# 00:28:53,833 --> 00:28:54,633
# จะเห็นว่า
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 852
# 00:28:54,900 --> 00:28:56,516
# 2 ปีเรายังอยู่ที่ 14%
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 853
# 00:28:56,516 --> 00:28:56,900
# นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 854
# 00:28:56,900 --> 00:28:58,166
# แต่ว่าการที่
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 855
# 00:28:58,833 --> 00:29:00,833
# หลายคนอาจจะมองว่าอัตราดอกเบี้ยขาขึ้นเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 856
# 00:29:00,833 --> 00:29:01,566
# มันอาจจะทําให้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 857
# 00:29:01,566 --> 00:29:02,300
# valuation
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 858
# 00:29:02,300 --> 00:29:03,900
# ของเงินลงทุนกลุ่มที่เป็น
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 859
# 00:29:03,900 --> 00:29:04,700
# prop fund
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 860
# 00:29:05,333 --> 00:29:05,766
# ลดลง
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 861
# 00:29:05,766 --> 00:29:07,533
# ลดลงทําไมเรายังลงทุนอยู่นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 862
# 00:29:07,566 --> 00:29:09,133
# จริง ๆ แล้วตัวนี้เป็น dividend
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 863
# 00:29:09,133 --> 00:29:09,933
# driver นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 864
# 00:29:10,133 --> 00:29:11,700
# เพราะฉะนั้นนโยบายการลงทุนของเราเนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 865
# 00:29:11,800 --> 00:29:12,600
# จริง ๆ หลัก ๆ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 866
# 00:29:13,033 --> 00:29:15,266
# เรายังลงทุนเพื่อความยั่งยืนผ่าน
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 867
# 00:29:15,766 --> 00:29:18,566
# การรับดอกเบี้ย รับ แล้วก็ปันผลลัพธ์
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 868
# 00:29:18,800 --> 00:29:20,400
# หุ้นพื้นฐานยังดี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 869
# 00:29:20,533 --> 00:29:23,566
# เราก็คิดว่าหุ้นกลุ่มนี้ก็ยังเป็นหุ้นที่ทําให้เรามี
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 870
# 00:29:24,200 --> 00:29:25,700
# investment income อย่างต่อเนื่องนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 871
# 00:29:25,700 --> 00:29:29,935
# ซึ่งการปรับผ่อน เราก็อาจจะปรับเล็กน้อยตาม situation นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 872
# 00:29:29,935 --> 00:29:32,133
# แต่ว่าเราคิดว่ายังไงก็ตาม
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 873
# 00:29:32,366 --> 00:29:36,233
# เราจะไม่ได้เล่นหุ้นแบบที่ขายทํากําไร
# หรือขายขาดทุนทันทีนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 874
# 00:29:36,400 --> 00:29:38,762
# เรามองเป็นระยะยาวมากกว่านะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 875
# 00:29:41,166 --> 00:29:45,770
# คําถามสุดท้ายจะกลับไปเรื่องของการเติบโต
# ทิศทางการเติบโตปีนี้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 876
# 00:29:45,770 --> 00:29:46,866
# ทางบริษัทก็
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 877
# 00:29:47,400 --> 00:29:49,700
# คิดว่าคุณจะยังสามารถทําให้เติบโตได้เนี่ย
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 878
# 00:29:50,200 --> 00:29:52,039
# ตามภาคธุรกิจนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 879
# 00:29:52,039 --> 00:29:53,333
# ก็จะเป็น 2 ถึง 5% นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 880
# 00:29:53,766 --> 00:29:55,266
# แล้วก็วางเป้าหมายไว้
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 881
# 00:29:55,800 --> 00:30:00,787
# ว่าเรายังสามารถจะเติบโตได้อย่างต่อเนื่อง
# ด้วย combined ratio target อยู่ที่ประมาณ 95% นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 882
# 00:30:03,800 --> 00:30:04,833
# ค่ะ โอเคค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 883
# 00:30:05,066 --> 00:30:07,633
# งั้นวันนี้นะคะ ไทยรีประกันชิวิต ก็ขอบคุณนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 884
# 00:30:07,666 --> 00:30:10,800
# ที่ให้ความสนใจนะคะ และหากว่ามีคําถามนะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 885
# 00:30:11,000 --> 00:30:13,066
# ก็สามารถจะสอบถามมาที่ IR
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 886
# 00:30:13,233 --> 00:30:14,600
# ของบริษัทได้นะคะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 887
# 00:30:15,433 --> 00:30:16,666
# จนกว่าจะพบกันใหม่ค่ะ สวัสดีค่ะ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 888
# 00:30:17,633 --> 00:30:18,433
# สวัสดีครับ
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# 889
# 00:30:27,866 --> 00:30:28,666
# i
#
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful

# %%
df = pd.DataFrame(results, columns=["symbol", "path", "transcript"])

# %%
df.to_csv(ROOT_PATH / "train_metadata.tsv", sep="\t", index=False)
